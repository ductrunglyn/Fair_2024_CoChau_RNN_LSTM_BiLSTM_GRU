# %% [markdown]
# # Import thư viện

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Flatten, SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Đọc dữ liệu

# %%
# Đọc dữ liệu vào DataFrame
df_t_2 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_2\TongMua_KaNak_AnKhe_t-2.csv')
df_t_4 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_4\TongMua_KaNak_AnKhe_t-4.csv')
df_t_6 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_6\TongMua_KaNak_AnKhe_t-6.csv')
df_t_8 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_8\TongMua_KaNak_AnKhe_t-8.csv')

# Xử lý dữ liệu bị thiếu
df_t_2 = df_t_2.dropna()
df_t_4 = df_t_4.dropna()
df_t_6 = df_t_6.dropna()
df_t_8 = df_t_8.dropna()

# %% [markdown]
# # Tạo dữ liệu huấn luyện

# %%
def create_dataset(X, y, n_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:i+n_steps])
        ys.append(y[i+n_steps])
    return np.array(Xs), np.array(ys)

# %% [markdown]
# # Chuẩn hóa và chia bộ dữ liệu

# %%
# Chuẩn hóa dữ liệu
def scaler(df, time_steps):
    scaler = MinMaxScaler()
    X = df[['Tổng lưu lượng xả (m³/s)[Thực tế]', 'Lưu lượng đến hồ (m³/s)', 'Sum_Mua']]
    y = df[['Lưu lượng đến hồ (m³/s)']]
    X = scaler.fit_transform(X)
    y = scaler.fit_transform(y)

    # Tạo nhãn cho dữ liệu
    X_data, y_data = create_dataset(X, y, time_steps)

    return scaler, X_data, y_data

# %%
# Chuẩn hóa dữ liệu
def split_data(X_data, y_data, time_steps):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.7)
    val_length = int((len(X_data) - train_length) / 2)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_val, y_val = X_data[train_length:train_length+val_length], y_data[train_length:train_length+val_length]
    X_test, y_test = X_data[-val_length:], y_data[-val_length:]

    # Reshape dữ liệu đầu vào
    X_train = X_train.reshape(X_train.shape[0], time_steps, X_train.shape[2])
    X_val = X_val.reshape(X_val.shape[0], time_steps, X_val.shape[2])
    X_test = X_test.reshape(X_test.shape[0], time_steps, X_test.shape[2])

    print("Kích thước tập huấn luyện:", len(X_train))
    print("Kích thước tập validation:", len(X_val))
    print("Kích thước tập kiểm tra:", len(X_test))

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# # Xây dựng mô hình RNN

# %%
def train_model(X_train, y_train, X_val, y_val, epochs, batch_size, save_best_model):
    # Tạo mô hình RNN
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = Sequential([
        SimpleRNN(32, input_shape=input_shape, activation='tanh', return_sequences=False),
        Dropout(0.5),
        Dense(1)
    ])

    model.summary()

    # Compile mô hình
    model.compile(optimizer=Adam(learning_rate=1e-3), loss='mean_squared_error')

    # Lưu lại model tốt nhất
    model_checkpoint = ModelCheckpoint(save_best_model, save_best_only=True, monitor='val_loss', mode='min', verbose=1)

    # Train the model
    history = model.fit(X_train, y_train, 
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=model_checkpoint)
    
    return model, history

# %%
import matplotlib.pyplot as plt

def plot_loss_model(history):
    # Trích xuất giá trị loss trên tập huấn luyện và kiểm tra
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Vẽ biểu đồ
    plt.figure(figsize=(8, 5))
    plt.plot(train_loss, linestyle='-', label='Train loss')
    plt.plot(val_loss, linestyle='-', label='Val loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train loss and Val loss')
    plt.yscale('log')  # Scale y-axis to logarithmic scale
    plt.legend()  # Thêm nhãn chú thích
    plt.show()

# %% [markdown]
# # Dự đoán trên tập kiểm tra và tính toán các chỉ số

# %%
def evaluate(model, X_test, y_test):
    # Dự đoán trên tập validation
    y_pred = model.predict(X_test)

    # Calculate evaluation metrics
    mse_test = mean_squared_error(y_test, y_pred)
    mae_test = mean_absolute_error(y_test, y_pred)
    r2_test = r2_score(y_test, y_pred)
    rmse_test = sqrt(mse_test)
    rmae_test = sqrt(mae_test)

    # Print evaluation results
    print("Mean Squared Error (MSE) on test set:", mse_test)
    print("Mean Absolute Error (MAE) on test set:", mae_test)
    print("R-squared (R2) on test set:", r2_test)
    print("Root Mean Squared Error (RMSE) on test set:", rmse_test)
    print("Root Mean Absolute Error (RMAE) on test set:", rmae_test)

    return y_pred

# %% [markdown]
# # Hiển thị biểu đồ kết quả

# %%
# Khôi phục dữ liệu sau chuẩn hóa
def inverse_transform_data(scaler, y_pred, y_test):
    y_pred_predict = scaler.inverse_transform(y_pred)
    y_pred_predict = pd.DataFrame(y_pred_predict)

    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test)

    return y_pred_predict, y_test

# %%
def plot_data_goc(df):
    # Vẽ biểu đồ dữ liệu gốc
    plt.figure(figsize=(15, 6))
    plt.plot(df['thoi_gian_KaNak'], df['Tổng lưu lượng xả (m³/s)[Thực tế]'], label='Tổng lưu lượng xả')
    plt.plot(df['thoi_gian_KaNak'], df['Lưu lượng đến hồ (m³/s)'], label='Lưu lượng đến hồ')
    plt.plot(df['thoi_gian_KaNak'], df['Sum_Mua'], label='Tổng lượng mưa')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng (m³/s)')
    plt.title('Biểu đồ lưu lượng')
    plt.legend()
    plt.show()

def plot_data_predict(y_test, y_pred_predict):
    # Biểu đồ giá trị dự đoán và thực tế trên tập test
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_pred_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán trên tập kiểm tra')
    plt.legend()
    plt.show()

def plot_bat_thuong_test(y_test, y_pred_predict):
    # Biểu đồ giá trị dự đoán và giá trị thực tế ở điểm bất thường trên tập test
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_pred_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán bất thường trên tập kiểm tra')
    plt.legend()

    # Chỉ hiển thị một đoạn nhỏ của biểu đồ
    start_index = 0
    end_index = 1000
    plt.xlim(start_index, end_index)
    plt.show() 

def plot_data_chi_dinh(scaler, model, X_train, y_train):
    X_data_slipt = X_train[15290:17980]
    y_data_slipt = y_train[15290:17980]

    # Dự đoán trên đoạn dữ liệu chỉ định
    y_data_slipt_predict = model.predict(X_data_slipt)

    # Khôi phục dữ liệu sau chuẩn hóa
    y_data_slipt_predict = scaler.inverse_transform(y_data_slipt_predict)
    y_data_slipt_predict = pd.DataFrame(y_data_slipt_predict)
    y_data_slipt = scaler.inverse_transform(y_data_slipt)
    y_data_slipt = pd.DataFrame(y_data_slipt)

    # Biểu đồ giá trị dự đoán và giá trị thực tế trên đoạn dữ liệu gốc bất kỳ
    plt.figure(figsize=(15, 6))
    plt.plot(y_data_slipt, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_data_slipt_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán bất thường trên dữ liệu gốc')
    plt.legend()
    plt.show()

# %% [markdown]
# # Chạy mô hình

# %%
# Các tham số cho mô hình
# time_steps = 24 * 3
time_steps = 1
epochs = 300
batch_size = 24
save_best_model_t_2 = './best_model/Model_RNN_t-2.hdf5'
save_best_model_t_4 = './best_model/Model_RNN_t-4.hdf5'
save_best_model_t_6 = './best_model/Model_RNN_t-6.hdf5'
save_best_model_t_8 = './best_model/Model_RNN_t-8.hdf5'

# Chuẩn hóa dữ liệu
scaler_t_2, X_data_t_2, y_data_t_2 = scaler(df_t_2, time_steps)
scaler_t_4, X_data_t_4, y_data_t_4 = scaler(df_t_4, time_steps)
scaler_t_6, X_data_t_6, y_data_t_6 = scaler(df_t_6, time_steps)
scaler_t_8, X_data_t_8, y_data_t_8 = scaler(df_t_8, time_steps)

# Chia dữ liệu
print("Data cách 2 giờ")
X_train_t_2, y_train_t_2, X_val_t_2, y_val_t_2, X_test_t_2, y_test_t_2 = split_data(X_data_t_2, y_data_t_2, time_steps)
print()
print("Data cách 4 giờ")
X_train_t_4, y_train_t_4, X_val_t_4, y_val_t_4, X_test_t_4, y_test_t_4 = split_data(X_data_t_4, y_data_t_4, time_steps)
print()
print("Data cách 6 giờ")
X_train_t_6, y_train_t_6, X_val_t_6, y_val_t_6, X_test_t_6, y_test_t_6 = split_data(X_data_t_6, y_data_t_6, time_steps)
print("Data cách 8 giờ")
X_train_t_8, y_train_t_8, X_val_t_8, y_val_t_8, X_test_t_8, y_test_t_8 = split_data(X_data_t_8, y_data_t_8, time_steps)
# Out:
# Data cách 2 giờ
# Kích thước tập huấn luyện: 20991
# Kích thước tập validation: 4498
# Kích thước tập kiểm tra: 4498
#
# Data cách 4 giờ
# Kích thước tập huấn luyện: 19081
# Kích thước tập validation: 4089
# Kích thước tập kiểm tra: 4089
#
# Data cách 6 giờ
# Kích thước tập huấn luyện: 17171
# Kích thước tập validation: 3680
# Kích thước tập kiểm tra: 3680
# Data cách 8 giờ
# Kích thước tập huấn luyện: 17170
# Kích thước tập validation: 3679
# Kích thước tập kiểm tra: 3679

# %%
# Training mô hình
# print("Training mô hình RNN với data cách 2 giờ")
# model_t_2, history_t_2 = train_model(X_train_t_2, y_train_t_2, X_val_t_2, y_val_t_2, 
#                                      epochs, batch_size, save_best_model_t_2)
# print()
# print("Training mô hình RNN với data cách 4 giờ")
# model_t_4, history_t_4 = train_model(X_train_t_4, y_train_t_4, X_val_t_4, y_val_t_4, 
#                                      epochs, batch_size, save_best_model_t_4)
# print()
# print("Training mô hình RNN với data cách 6 giờ")
# model_t_6, history_t_6 = train_model(X_train_t_6, y_train_t_6, X_val_t_6, y_val_t_6, 
#                                      epochs, batch_size, save_best_model_t_6)
print("Training mô hình RNN với data cách 8 giờ")
model_t_8, history_t_8 = train_model(X_train_t_8, y_train_t_8, X_val_t_8, y_val_t_8, 
                                     epochs, batch_size, save_best_model_t_8)
print()

# Vẽ biểu đồ train_loss và val_loss
# print("Train loss và Val loss của data cách 2 giờ")
# plot_loss_model(history_t_2)
# print()
# print("Train loss và Val loss của data cách 4 giờ")
# plot_loss_model(history_t_4)
# print()
# print("Train loss và Val loss của data cách 6 giờ")
# plot_loss_model(history_t_6)
# print()
print("Train loss và Val loss của data cách 8 giờ")
plot_loss_model(history_t_8)
# Out:
# Training mô hình RNN với data cách 8 giờ
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\simple_rnn.py:130: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 32)                1152
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 1185 (4.63 KB)
# Trainable params: 1185 (4.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/300
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 700/716 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 1: val_loss improved from inf to 0.00053, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 5.2981e-04
# Epoch 2/300
# 132/716 [====>.........................] - ETA: 0s - loss: 0.0016
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 676/716 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 2: val_loss improved from 0.00053 to 0.00025, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 0.0012 - val_loss: 2.4773e-04
# Epoch 3/300
# 688/716 [===========================>..] - ETA: 0s - loss: 7.9912e-04
# Epoch 3: val_loss did not improve from 0.00025
# 716/716 [==============================] - 1s 1ms/step - loss: 7.9057e-04 - val_loss: 2.4994e-04
# Epoch 4/300
# 684/716 [===========================>..] - ETA: 0s - loss: 6.7711e-04
# Epoch 4: val_loss improved from 0.00025 to 0.00023, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 6.6704e-04 - val_loss: 2.2968e-04
# Epoch 5/300
# 707/716 [============================>.] - ETA: 0s - loss: 5.8898e-04
# Epoch 5: val_loss did not improve from 0.00023
# 716/716 [==============================] - 1s 1ms/step - loss: 5.8977e-04 - val_loss: 2.4170e-04
# Epoch 6/300
# 674/716 [===========================>..] - ETA: 0s - loss: 5.2176e-04
# Epoch 6: val_loss did not improve from 0.00023
# 716/716 [==============================] - 1s 1ms/step - loss: 5.3968e-04 - val_loss: 2.3231e-04
# Epoch 7/300
# 710/716 [============================>.] - ETA: 0s - loss: 5.7645e-04
# Epoch 7: val_loss improved from 0.00023 to 0.00021, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 5.7390e-04 - val_loss: 2.1012e-04
# Epoch 8/300
# 709/716 [============================>.] - ETA: 0s - loss: 6.1489e-04
# Epoch 8: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 6.1646e-04 - val_loss: 2.4798e-04
# Epoch 9/300
# 700/716 [============================>.] - ETA: 0s - loss: 5.3531e-04
# Epoch 9: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 5.4063e-04 - val_loss: 2.2216e-04
# Epoch 10/300
# 682/716 [===========================>..] - ETA: 0s - loss: 4.7389e-04
# Epoch 10: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 4.7154e-04 - val_loss: 2.0953e-04
# Epoch 11/300
# 677/716 [===========================>..] - ETA: 0s - loss: 5.3018e-04
# Epoch 11: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 5.2660e-04 - val_loss: 2.3282e-04
# Epoch 12/300
# 712/716 [============================>.] - ETA: 0s - loss: 5.4048e-04
# Epoch 12: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 5.3879e-04 - val_loss: 2.3658e-04
# Epoch 13/300
# 698/716 [============================>.] - ETA: 0s - loss: 5.1260e-04
# Epoch 13: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 5.0770e-04 - val_loss: 2.0692e-04
# Epoch 14/300
# 680/716 [===========================>..] - ETA: 0s - loss: 4.9935e-04
# Epoch 14: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9361e-04 - val_loss: 2.0649e-04
# Epoch 15/300
# 694/716 [============================>.] - ETA: 0s - loss: 4.9521e-04
# Epoch 15: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 5.0923e-04 - val_loss: 2.6410e-04
# Epoch 16/300
# 700/716 [============================>.] - ETA: 0s - loss: 4.8088e-04
# Epoch 16: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 4.8721e-04 - val_loss: 2.3195e-04
# Epoch 17/300
# 690/716 [===========================>..] - ETA: 0s - loss: 4.8711e-04
# Epoch 17: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 4.8209e-04 - val_loss: 2.0656e-04
# Epoch 18/300
# 711/716 [============================>.] - ETA: 0s - loss: 4.9777e-04
# Epoch 18: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9692e-04 - val_loss: 2.0527e-04
# Epoch 19/300
# 710/716 [============================>.] - ETA: 0s - loss: 5.0374e-04
# Epoch 19: val_loss did not improve from 0.00021
# 716/716 [==============================] - 1s 1ms/step - loss: 5.0950e-04 - val_loss: 2.1660e-04
# Epoch 20/300
# 691/716 [===========================>..] - ETA: 0s - loss: 4.8365e-04
# Epoch 20: val_loss improved from 0.00021 to 0.00020, saving model to ./best_model\Model_RNN_t-8.hdf5
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9744e-04 - val_loss: 1.9767e-04
# Epoch 21/300
# 697/716 [============================>.] - ETA: 0s - loss: 4.9874e-04
# Epoch 21: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 5.0225e-04 - val_loss: 2.0344e-04
# Epoch 22/300
# 684/716 [===========================>..] - ETA: 0s - loss: 4.8946e-04
# Epoch 22: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9046e-04 - val_loss: 2.1030e-04
# Epoch 23/300
# 705/716 [============================>.] - ETA: 0s - loss: 4.7773e-04
# Epoch 23: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.7571e-04 - val_loss: 2.0523e-04
# Epoch 24/300
# 691/716 [===========================>..] - ETA: 0s - loss: 4.6784e-04
# Epoch 24: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.
val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.4231e-04 - val_loss: 2.0842e-04
# Epoch 288/300
# 705/716 [============================>.] - ETA: 0s - loss: 5.0661e-04
# Epoch 288: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 5.1132e-04 - val_loss: 2.4048e-04
# Epoch 289/300
# 693/716 [============================>.] - ETA: 0s - loss: 4.3293e-04
# Epoch 289: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.4860e-04 - val_loss: 2.4092e-04
# Epoch 290/300
# 693/716 [============================>.] - ETA: 0s - loss: 4.3543e-04
# Epoch 290: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.4265e-04 - val_loss: 2.2074e-04
# Epoch 291/300
# 688/716 [===========================>..] - ETA: 0s - loss: 4.9582e-04
# Epoch 291: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9450e-04 - val_loss: 2.2748e-04
# Epoch 292/300
# 674/716 [===========================>..] - ETA: 0s - loss: 5.0441e-04
# Epoch 292: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9420e-04 - val_loss: 2.2264e-04
# Epoch 293/300
# 696/716 [============================>.] - ETA: 0s - loss: 4.2696e-04
# Epoch 293: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.2567e-04 - val_loss: 2.1338e-04
# Epoch 294/300
# 690/716 [===========================>..] - ETA: 0s - loss: 4.7789e-04
# Epoch 294: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.7619e-04 - val_loss: 2.2644e-04
# Epoch 295/300
# 702/716 [============================>.] - ETA: 0s - loss: 4.8330e-04
# Epoch 295: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.8371e-04 - val_loss: 2.1432e-04
# Epoch 296/300
# 679/716 [===========================>..] - ETA: 0s - loss: 4.9406e-04
# Epoch 296: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.9129e-04 - val_loss: 2.2247e-04
# Epoch 297/300
# 680/716 [===========================>..] - ETA: 0s - loss: 4.6544e-04
# Epoch 297: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.6843e-04 - val_loss: 2.0214e-04
# Epoch 298/300
# 680/716 [===========================>..] - ETA: 0s - loss: 4.7520e-04
# Epoch 298: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.7678e-04 - val_loss: 2.1061e-04
# Epoch 299/300
# 686/716 [===========================>..] - ETA: 0s - loss: 4.6075e-04
# Epoch 299: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.6211e-04 - val_loss: 2.3124e-04
# Epoch 300/300
# 682/716 [===========================>..] - ETA: 0s - loss: 4.8519e-04
# Epoch 300: val_loss did not improve from 0.00020
# 716/716 [==============================] - 1s 1ms/step - loss: 4.8487e-04 - val_loss: 2.4016e-04
#
# Train loss và Val loss của data cách 8 giờ

# %%
# Đánh giá mô hình trên tập test
# print("Đánh giá mô hình RNN với data cách 2 giờ")
# y_pred_t_2 = evaluate(model_t_2, X_test_t_2, y_test_t_2)
# print()
# print("Đánh giá mô hình RNN với data cách 4 giờ")
# y_pred_t_4 = evaluate(model_t_4, X_test_t_4, y_test_t_4)
# print()
# print("Đánh giá mô hình RNN với data cách 6 giờ")
# y_pred_t_6 = evaluate(model_t_6, X_test_t_6, y_test_t_6)
print()
print("Đánh giá mô hình RNN với data cách 8 giờ")
y_pred_t_8 = evaluate(model_t_8, X_test_t_8, y_test_t_8)
# Out:
# Đánh giá mô hình RNN với data cách 8 giờ
# 115/115 [==============================] - 0s 1ms/step
# Mean Squared Error (MSE) on test set: 0.00018674109716660254
# Mean Absolute Error (MAE) on test set: 0.00898684094460793
# R-squared (R2) on test set: 0.7804339420260005
# Root Mean Squared Error (RMSE) on test set: 0.013665324627194282
# Root Mean Absolute Error (RMAE) on test set: 0.09479895012397516

# %%
# Chuẩn hóa lại dữ liệu sau để vẽ mô hình
# y_pred_predict_t_2, y_test_t_2 = inverse_transform_data(scaler_t_2, y_pred_t_2, y_test_t_2)
# y_pred_predict_t_4, y_test_t_4 = inverse_transform_data(scaler_t_4, y_pred_t_4, y_test_t_4)
# y_pred_predict_t_6, y_test_t_6 = inverse_transform_data(scaler_t_6, y_pred_t_6, y_test_t_6)
y_pred_predict_t_8, y_test_t_8 = inverse_transform_data(scaler_t_8, y_pred_t_8, y_test_t_8)

# Vẽ các hình data gốc
# print("Dữ liệu gốc cách 2 giờ")
# plot_data_goc(df_t_2)
# print()
# print("Dữ liệu gốc cách 4 giờ")
# plot_data_goc(df_t_4)
# print()
# print("Dữ liệu gốc cách 6 giờ")
# plot_data_goc(df_t_6)
# print()
# print("Dữ liệu gốc cách 8 giờ")
# plot_data_goc(df_t_8)
# print()

# Biểu đồ giá trị dự đoán và thực tế trên tập test
# print("Dữ liệu dự đoán với dữ liệu cách 2 giờ")
# plot_data_predict(y_test_t_2, y_pred_predict_t_2)
# print()
# print("Dữ liệu dự đoán với dữ liệu cách 4 giờ")
# plot_data_predict(y_test_t_4, y_pred_predict_t_4)
# print()
# print("Dữ liệu dự đoán với dữ liệu cách 6 giờ")
# plot_data_predict(y_test_t_6, y_pred_predict_t_6)
# print()
print("Dữ liệu dự đoán với dữ liệu cách 8 giờ")
plot_data_predict(y_test_t_8, y_pred_predict_t_8)
print()

# Biểu đồ giá trị dự đoán và giá trị thực tế ở điểm bất thường trên tập test
# print("Dữ liệu dự đoán bất thường với dữ liệu cách 2 giờ")
# plot_bat_thuong_test(y_test_t_2, y_pred_predict_t_2)
# print()
# print("Dữ liệu dự đoán bất thường với dữ liệu cách 4 giờ")
# plot_bat_thuong_test(y_test_t_4, y_pred_predict_t_4)
# print()
# print("Dữ liệu dự đoán bất thường với dữ liệu cách 6 giờ")
# plot_bat_thuong_test(y_test_t_6, y_pred_predict_t_6)
# print()
print("Dữ liệu dự đoán bất thường với dữ liệu cách 8 giờ")
plot_bat_thuong_test(y_test_t_8, y_pred_predict_t_8)
print()

# Vẽ biểu đồ tại điểm bất thường trên dữ liệu gốc
# print("Điểm bất thường trên dữ liệu gốc cách 2 giờ")
# plot_data_chi_dinh(scaler_t_2, model_t_2, X_train_t_2, y_train_t_2)
# print()
# print("Điểm bất thường trên dữ liệu gốc cách 4 giờ")
# plot_data_chi_dinh(scaler_t_4, model_t_4, X_train_t_4, y_train_t_4)
# print()
# print("Điểm bất thường trên dữ liệu gốc cách 6 giờ")
# plot_data_chi_dinh(scaler_t_6, model_t_6, X_train_t_6, y_train_t_6)
# print()
print("Điểm bất thường trên dữ liệu gốc cách 8 giờ")
plot_data_chi_dinh(scaler_t_8, model_t_8, X_train_t_8, y_train_t_8)
# Out:
# Dữ liệu dự đoán với dữ liệu cách 8 giờ
# Dữ liệu dự đoán bất thường với dữ liệu cách 8 giờ
# Điểm bất thường trên dữ liệu gốc cách 8 giờ
# 59/59 [==============================] - 0s 759us/step
