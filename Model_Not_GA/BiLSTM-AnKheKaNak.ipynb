# %% [markdown]
# # Import thư viện

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Flatten, Bidirectional
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Đọc dữ liệu

# %%
# Đọc dữ liệu vào DataFrame
df_t_2 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_2\TongMua_KaNak_AnKhe_t-2.csv')
df_t_4 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_4\TongMua_KaNak_AnKhe_t-4.csv')
df_t_6 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_6\TongMua_KaNak_AnKhe_t-6.csv')
df_t_8 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_8\TongMua_KaNak_AnKhe_t-8.csv')

# Xử lý dữ liệu bị thiếu
df_t_2 = df_t_2.dropna()
df_t_4 = df_t_4.dropna()
df_t_6 = df_t_6.dropna()
df_t_8 = df_t_8.dropna()

# %% [markdown]
# # Tạo dữ liệu huấn luyện

# %%
def create_dataset(X, y, n_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:i+n_steps])
        ys.append(y[i+n_steps])
    return np.array(Xs), np.array(ys)

# %% [markdown]
# # Chuẩn hóa và chia bộ dữ liệu cho mô hình LSTM

# %%
# Chuẩn hóa dữ liệu
def scaler(df, time_steps):
    scaler = MinMaxScaler()
    X = df[['Tổng lưu lượng xả (m³/s)[Thực tế]', 'Lưu lượng đến hồ (m³/s)', 'Sum_Mua']]
    y = df[['Lưu lượng đến hồ (m³/s)']]
    X = scaler.fit_transform(X)
    y = scaler.fit_transform(y)

    # Tạo nhãn cho dữ liệu
    X_data, y_data = create_dataset(X, y, time_steps)

    return scaler, X_data, y_data

# %%
# Chuẩn hóa dữ liệu
def split_data(X_data, y_data, time_steps):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.7)
    val_length = int((len(X_data) - train_length) / 2)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_val, y_val = X_data[train_length:train_length+val_length], y_data[train_length:train_length+val_length]
    X_test, y_test = X_data[-val_length:], y_data[-val_length:]

    # Reshape dữ liệu đầu vào
    X_train = X_train.reshape(X_train.shape[0], time_steps, X_train.shape[2])
    X_val = X_val.reshape(X_val.shape[0], time_steps, X_val.shape[2])
    X_test = X_test.reshape(X_test.shape[0], time_steps, X_test.shape[2])

    print("Kích thước tập huấn luyện:", len(X_train))
    print("Kích thước tập validation:", len(X_val))
    print("Kích thước tập kiểm tra:", len(X_test))

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# # Xây dựng mô hình BiLSTM

# %%
def train_model(X_train, y_train, X_val, y_val, epochs, batch_size, save_best_model):
    # Xây dựng mô hình LSTM
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = Sequential()
    model.add(Bidirectional(LSTM(32, input_shape=input_shape, activation='tanh', return_sequences=False)))
    model.add(Dropout(0.5))
    model.add(Dense(1))

    # Compile mô hình
    model.compile(optimizer=Adam(learning_rate=1e-3), loss='mean_squared_error')

    # Lưu lại model tốt nhất
    model_checkpoint = ModelCheckpoint(save_best_model, save_best_only=True, monitor='val_loss', mode='min', verbose=1)

    # Train the model
    history = model.fit(X_train, y_train, 
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=model_checkpoint)
    
    return model, history

# %%
import matplotlib.pyplot as plt

def plot_loss_model(history):
    # Trích xuất giá trị loss trên tập huấn luyện và kiểm tra
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Vẽ biểu đồ
    plt.figure(figsize=(8, 5))
    plt.plot(train_loss, linestyle='-', label='Train loss')
    plt.plot(val_loss, linestyle='-', label='Val loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train loss and Val loss')
    plt.yscale('log')  # Scale y-axis to logarithmic scale
    plt.legend()  # Thêm nhãn chú thích
    plt.show()

# %% [markdown]
# # Dự đoán trên tập kiểm tra và tính toán các chỉ số

# %%
def evaluate(model, X_test, y_test):
    # Dự đoán trên tập validation
    y_pred = model.predict(X_test)

    # Calculate evaluation metrics
    mse_test = mean_squared_error(y_test, y_pred)
    mae_test = mean_absolute_error(y_test, y_pred)
    r2_test = r2_score(y_test, y_pred)
    rmse_test = sqrt(mse_test)
    rmae_test = sqrt(mae_test)

    # Print evaluation results
    print("Mean Squared Error (MSE) on test set:", mse_test)
    print("Mean Absolute Error (MAE) on test set:", mae_test)
    print("R-squared (R2) on test set:", r2_test)
    print("Root Mean Squared Error (RMSE) on test set:", rmse_test)
    print("Root Mean Absolute Error (RMAE) on test set:", rmae_test)

    return y_pred

# %% [markdown]
# # Hiển thị biểu đồ kết quả

# %%
# Khôi phục dữ liệu sau chuẩn hóa
def inverse_transform_data(scaler, y_pred, y_test):
    y_pred_predict = scaler.inverse_transform(y_pred)
    y_pred_predict = pd.DataFrame(y_pred_predict)

    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test)

    return y_pred_predict, y_test

# %%
def plot_data_goc(df):
    # Vẽ biểu đồ dữ liệu gốc
    plt.figure(figsize=(15, 6))
    plt.plot(df['thoi_gian_KaNak'], df['Tổng lưu lượng xả (m³/s)[Thực tế]'], label='Tổng lưu lượng xả')
    plt.plot(df['thoi_gian_KaNak'], df['Lưu lượng đến hồ (m³/s)'], label='Lưu lượng đến hồ')
    plt.plot(df['thoi_gian_KaNak'], df['Sum_Mua'], label='Tổng lượng mưa')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng (m³/s)')
    plt.title('Biểu đồ lưu lượng')
    plt.legend()
    plt.show()

def plot_data_predict(y_test, y_pred_predict):
    # Biểu đồ giá trị dự đoán và thực tế trên tập test
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_pred_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán trên tập kiểm tra')
    plt.legend()
    plt.show()

def plot_bat_thuong_test(y_test, y_pred_predict):
    # Biểu đồ giá trị dự đoán và giá trị thực tế ở điểm bất thường trên tập test
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_pred_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán bất thường trên tập kiểm tra')
    plt.legend()

    # Chỉ hiển thị một đoạn nhỏ của biểu đồ
    start_index = 0
    end_index = 1000
    plt.xlim(start_index, end_index)
    plt.show() 

def plot_data_chi_dinh(scaler, model, X_train, y_train):
    X_data_slipt = X_train[15290:17980]
    y_data_slipt = y_train[15290:17980]

    # Dự đoán trên đoạn dữ liệu chỉ định
    y_data_slipt_predict = model.predict(X_data_slipt)

    # Khôi phục dữ liệu sau chuẩn hóa
    y_data_slipt_predict = scaler.inverse_transform(y_data_slipt_predict)
    y_data_slipt_predict = pd.DataFrame(y_data_slipt_predict)
    y_data_slipt = scaler.inverse_transform(y_data_slipt)
    y_data_slipt = pd.DataFrame(y_data_slipt)

    # Biểu đồ giá trị dự đoán và giá trị thực tế trên đoạn dữ liệu gốc bất kỳ
    plt.figure(figsize=(15, 6))
    plt.plot(y_data_slipt, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_data_slipt_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán bất thường trên dữ liệu gốc')
    plt.legend()
    plt.show()

# %% [markdown]
# # Chạy mô hình

# %%
# Các tham số cho mô hình
time_steps = 24 * 3
epochs = 300
batch_size = 24
save_best_model_t_2 = './best_model/Model_BiLSTM_t-2.hdf5'
save_best_model_t_4 = './best_model/Model_BiLSTM_t-4.hdf5'
save_best_model_t_6 = './best_model/Model_BiLSTM_t-6.hdf5'
save_best_model_t_8 = './best_model/Model_BiLSTM_t-8.hdf5'

# Chuẩn hóa dữ liệu
scaler_t_2, X_data_t_2, y_data_t_2 = scaler(df_t_2, time_steps)
scaler_t_4, X_data_t_4, y_data_t_4 = scaler(df_t_4, time_steps)
scaler_t_6, X_data_t_6, y_data_t_6 = scaler(df_t_6, time_steps)
scaler_t_8, X_data_t_8, y_data_t_8 = scaler(df_t_8, time_steps)

# Chia dữ liệu
print("Data cách 2 giờ")
X_train_t_2, y_train_t_2, X_val_t_2, y_val_t_2, X_test_t_2, y_test_t_2 = split_data(X_data_t_2, y_data_t_2, time_steps)
print()
print("Data cách 4 giờ")
X_train_t_4, y_train_t_4, X_val_t_4, y_val_t_4, X_test_t_4, y_test_t_4 = split_data(X_data_t_4, y_data_t_4, time_steps)
print()
print("Data cách 6 giờ")
X_train_t_6, y_train_t_6, X_val_t_6, y_val_t_6, X_test_t_6, y_test_t_6 = split_data(X_data_t_6, y_data_t_6, time_steps)
print()
print("Data cách 8 giờ")
X_train_t_8, y_train_t_8, X_val_t_8, y_val_t_8, X_test_t_8, y_test_t_8 = split_data(X_data_t_8, y_data_t_8, time_steps)
# Out:
# Data cách 8 giờ
# Kích thước tập huấn luyện: 17120
# Kích thước tập validation: 3669
# Kích thước tập kiểm tra: 3669

# %%
# # Training mô hình
print("Training mô hình Bi-LSTM với data cách 2 giờ")
model_t_2, history_t_2 = train_model(X_train_t_2, y_train_t_2, X_val_t_2, y_val_t_2, 
                                     epochs, batch_size, save_best_model_t_2)
print()
print("Training mô hình Bi-LSTM với data cách 4 giờ")
model_t_4, history_t_4 = train_model(X_train_t_4, y_train_t_4, X_val_t_4, y_val_t_4, 
                                     epochs, batch_size, save_best_model_t_4)
print()
print("Training mô hình Bi-LSTM với data cách 6 giờ")
model_t_6, history_t_6 = train_model(X_train_t_6, y_train_t_6, X_val_t_6, y_val_t_6, 
                                     epochs, batch_size, save_best_model_t_6)
print()
print("Training mô hình Bi-LSTM với data cách 8 giờ")
model_t_8, history_t_8 = train_model(X_train_t_8, y_train_t_8, X_val_t_8, y_val_t_8, 
                                     epochs, batch_size, save_best_model_t_8)
# Out:
# Training mô hình Bi-LSTM với data cách 8 giờ
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/300
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 713/714 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 1: val_loss improved from inf to 0.00098, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 18s 20ms/step - loss: 0.0019 - val_loss: 9.8234e-04
# Epoch 2/300
#   7/714 [..............................] - ETA: 13s - loss: 8.9170e-04
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 712/714 [============================>.] - ETA: 0s - loss: 9.5874e-04
# Epoch 2: val_loss improved from 0.00098 to 0.00070, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 9.5834e-04 - val_loss: 6.9575e-04
# Epoch 3/300
# 714/714 [==============================] - ETA: 0s - loss: 8.3913e-04
# Epoch 3: val_loss improved from 0.00070 to 0.00054, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 15s 21ms/step - loss: 8.3913e-04 - val_loss: 5.3616e-04
# Epoch 4/300
# 712/714 [============================>.] - ETA: 0s - loss: 7.6297e-04
# Epoch 4: val_loss improved from 0.00054 to 0.00047, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 7.6250e-04 - val_loss: 4.6628e-04
# Epoch 5/300
# 712/714 [============================>.] - ETA: 0s - loss: 7.6248e-04
# Epoch 5: val_loss improved from 0.00047 to 0.00038, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 7.6170e-04 - val_loss: 3.7768e-04
# Epoch 6/300
# 712/714 [============================>.] - ETA: 0s - loss: 6.4833e-04
# Epoch 6: val_loss improved from 0.00038 to 0.00035, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 15s 22ms/step - loss: 6.4934e-04 - val_loss: 3.5151e-04
# Epoch 7/300
# 712/714 [============================>.] - ETA: 0s - loss: 6.5360e-04
# Epoch 7: val_loss improved from 0.00035 to 0.00033, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 6.5260e-04 - val_loss: 3.3209e-04
# Epoch 8/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.9012e-04
# Epoch 8: val_loss did not improve from 0.00033
# 714/714 [==============================] - 15s 21ms/step - loss: 5.9041e-04 - val_loss: 3.5250e-04
# Epoch 9/300
# 714/714 [==============================] - ETA: 0s - loss: 6.1089e-04
# Epoch 9: val_loss improved from 0.00033 to 0.00028, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 23ms/step - loss: 6.1089e-04 - val_loss: 2.8065e-04
# Epoch 10/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.9743e-04
# Epoch 10: val_loss did not improve from 0.00028
# 714/714 [==============================] - 16s 22ms/step - loss: 5.9726e-04 - val_loss: 3.1011e-04
# Epoch 11/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.7023e-04
# Epoch 11: val_loss improved from 0.00028 to 0.00026, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 5.6976e-04 - val_loss: 2.6390e-04
# Epoch 12/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.4907e-04
# Epoch 12: val_loss improved from 0.00026 to 0.00026, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 5.4922e-04 - val_loss: 2.6266e-04
# Epoch 13/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.2383e-04
# Epoch 13: val_loss improved from 0.00026 to 0.00025, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 23ms/step - loss: 5.2364e-04 - val_loss: 2.5268e-04
# Epoch 14/300
# 714/714 [==============================] - ETA: 0s - loss: 4.9042e-04
# Epoch 14: val_loss improved from 0.00025 to 0.00024, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 4.9042e-04 - val_loss: 2.3704e-04
# Epoch 15/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.4779e-04
# Epoch 15: val_loss did not improve from 0.00024
# 714/714 [==============================] - 16s 22ms/step - loss: 5.4864e-04 - val_loss: 3.0113e-04
# Epoch 16/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.4846e-04
# Epoch 16: val_loss improved from 0.00024 to 0.00023, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 5.4781e-04 - val_loss: 2.2752e-04
# Epoch 17/300
# 714/714 [==============================] - ETA: 0s - loss: 4.9007e-04
# Epoch 17: val_loss improved from 0.00023 to 0.00022, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 4.9007e-04 - val_loss: 2.2479e-04
# Epoch 18/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.1254e-04
# Epoch 18: val_loss did not improve from 0.00022
# 714/714 [==============================] - 15s 21ms/step - loss: 5.1236e-04 - val_loss: 2.2871e-04
# Epoch 19/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.1861e-04
# Epoch 19: val_loss did not improve from 0.00022
# 714/714 [==============================] - 15s 21ms/step - loss: 5.1864e-04 - val_loss: 2.2594e-04
# Epoch 20/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5520e-04
# Epoch 20: val_loss improved from 0.00022 to 0.00021, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 15s 22ms/step - loss: 4.5556e-04 - val_loss: 2.1062e-04
# Epoch 21/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5542e-04
# Epoch 21: val_loss did not improve from 0.00021
# 714/714 [==============================] - 15s 21ms/step - loss: 4.5524e-04 - val_loss: 2.1098e-04
# Epoch 22/300
# 714/714 [==============================] - ETA: 0s - loss: 5.4094e-04
# Epoch 22: val_loss did not improve from 0.00021
# 714/714 [==============================] - 15s 21ms/step - loss: 5.4094e-04 - val_loss: 2.4045e-04
# Epoch 23/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7943e-04
# Epoch 23: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7922e-04 - val_loss: 2.0996e-04
# Epoch 24/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7403e-04
# Epoch 24: val_loss did not improve from 0.00021
# 714/714 [==============================] - 15s 22ms/step - loss: 4.7422e-04 - val_loss: 2.1038e-04
# Epoch 25/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5530e-04
# Epoch 25: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 15s 21ms/step - loss: 4.5629e-04 - val_loss: 2.0784e-04
# Epoch 26/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7913e-04
# Epoch 26: val_loss improved from 0.00021 to 0.00020, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7910e-04 - val_loss: 1.9893e-04
# Epoch 27/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6204e-04
# Epoch 27: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6204e-04 - val_loss: 2.0219e-04
# Epoch 28/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.0430e-04
# Epoch 28: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 5.0381e-04 - val_loss: 2.0318e-04
# Epoch 29/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5541e-04
# Epoch 29: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5541e-04 - val_loss: 2.0492e-04
# Epoch 30/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2454e-04
# Epoch 30: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2454e-04 - val_loss: 2.0239e-04
# Epoch 31/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7347e-04
# Epoch 31: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7347e-04 - val_loss: 2.9873e-04
# Epoch 32/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6474e-04
# Epoch 32: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6474e-04 - val_loss: 2.0124e-04
# Epoch 33/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4448e-04
# Epoch 33: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4448e-04 - val_loss: 2.1974e-04
# Epoch 34/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5040e-04
# Epoch 34: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5040e-04 - val_loss: 1.9971e-04
# Epoch 35/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6986e-04
# Epoch 35: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6986e-04 - val_loss: 2.1050e-04
# Epoch 36/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5625e-04
# Epoch 36: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5625e-04 - val_loss: 2.0205e-04
# Epoch 37/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.8669e-04
# Epoch 37: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.8615e-04 - val_loss: 2.5849e-04
# Epoch 38/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.8442e-04
# Epoch 38: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.8365e-04 - val_loss: 2.0550e-04
# Epoch 39/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5418e-04
# Epoch 39: val_loss did not improve from 0.00020
# 714/714 [==============================] - 15s 22ms/step - loss: 4.5400e-04 - val_loss: 2.1756e-04
# Epoch 40/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6390e-04
# Epoch 40: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6374e-04 - val_loss: 2.0266e-04
# Epoch 41/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7615e-04
# Epoch 41: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7564e-04 - val_loss: 2.0152e-04
# Epoch 42/300
# 714/714 [==============================] - ETA: 0s - loss: 5.2344e-04
# Epoch 42: val_loss did not improve from 0.00020
# 714/714 [==============================] - 16s 22ms/step - loss: 5.2344e-04 - val_loss: 2.0028e-04
# Epoch 43/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5639e-04
# Epoch 43: val_loss did not improve from 0.00020
# 714/714 [==============================] - 15s 22ms/step - loss: 4.5646e-04 - val_loss: 2.2183e-04
# Epoch 44/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1799e-04
# Epoch 44: val_loss improved from 0.00020 to 0.00019, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1747e-04 - val_loss: 1.9436e-04
# Epoch 45/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4997e-04
# Epoch 45: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5146e-04 - val_loss: 2.1001e-04
# Epoch 46/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5082e-04
# Epoch 46: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5024e-04 - val_loss: 2.0010e-04
# Epoch 47/300
# 714/714 [==============================] - ETA: 0s - loss: 4.9400e-04
# Epoch 47: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.9400e-04 - val_loss: 2.3849e-04
# Epoch 48/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5727e-04
# Epoch 48: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5719e-04 - val_loss: 2.1551e-04
# Epoch 49/300
# 714/714 [==============================] - ETA: 0s - loss: 4.8005e-04
# Epoch 49: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.8005e-04 - val_loss: 2.4331e-04
# Epoch 50/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5160e-04
# Epoch 50: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5141e-04 - val_loss: 2.2396e-04
# Epoch 51/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7927e-04
# Epoch 51: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.7927e-04 - val_loss: 2.0241e-04
# Epoch 52/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5721e-04
# Epoch 52: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5710e-04 - val_loss: 2.0632e-04
# Epoch 53/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1329e-04
# Epoch 53: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.1329e-04 - val_loss: 2.1621e-04
# Epoch 54/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4936e-04
# Epoch 54: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5046e-04 - val_loss: 1.9973e-04
# Epoch 55/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7261e-04
# Epoch 55: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7261e-04 - val_loss: 2.1301e-04
# Epoch 56/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7736e-04
# Epoch 56: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7723e-04 - val_loss: 1.9553e-04
# Epoch 57/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.6660e-04
# Epoch 57: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6626e-04 - val_loss: 2.0729e-04
# Epoch 58/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2308e-04
# Epoch 58: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2308e-04 - val_loss: 2.0629e-04
# Epoch 59/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4701e-04
# Epoch 59: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4665e-04 - val_loss: 2.4685e-04
# Epoch 60/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7231e-04
# Epoch 60: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7212e-04 - val_loss: 2.1318e-04
# Epoch 61/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5955e-04
# Epoch 61: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5898e-04 - val_loss: 2.3308e-04
# Epoch 62/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4242e-04
# Epoch 62: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4227e-04 - val_loss: 2.5568e-04
# Epoch 63/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5039e-04
# Epoch 63: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4987e-04 - val_loss: 2.3743e-04
# Epoch 64/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.6870e-04
# Epoch 64: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.6819e-04 - val_loss: 2.2166e-04
# Epoch 65/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7988e-04
# Epoch 65: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7978e-04 - val_loss: 2.1451e-04
# Epoch 66/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4595e-04
# Epoch 66: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4595e-04 - val_loss: 2.0988e-04
# Epoch 67/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4352e-04
# Epoch 67: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4286e-04 - val_loss: 2.1991e-04
# Epoch 68/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1251e-04
# Epoch 68: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.1470e-04 - val_loss: 2.2237e-04
# Epoch 69/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4349e-04
# Epoch 69: val_loss improved from 0.00019 to 0.00019, saving model to ./best_model\Model_BiLSTM_t-8.hdf5
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4447e-04 - val_loss: 1.9361e-04
# Epoch 70/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0324e-04
# Epoch 70: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0324e-04 - val_loss: 2.0136e-04
# Epoch 71/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4357e-04
# Epoch 71: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4351e-04 - val_loss: 2.0935e-04
# Epoch 72/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4447e-04
# Epoch 72: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.4447e-04 - val_loss: 2.0144e-04
# Epoch 73/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4389e-04
# Epoch 73: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4376e-04 - val_loss: 2.2420e-04
# Epoch 74/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3774e-04
# Epoch 74: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3774e-04 - val_loss: 2.1428e-04
# Epoch 75/300
# 714/714 [==============================] - ETA: 0s - loss: 4.8457e-04
# Epoch 75: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.8457e-04 - val_loss: 2.3164e-04
# Epoch 76/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2434e-04
# Epoch 76: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2434e-04 - val_loss: 2.1197e-04
# Epoch 77/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4980e-04
# Epoch 77: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4965e-04 - val_loss: 2.1736e-04
# Epoch 78/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4738e-04
# Epoch 78: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4719e-04 - val_loss: 2.2340e-04
# Epoch 79/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4831e-04
# Epoch 79: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4831e-04 - val_loss: 2.2249e-04
# Epoch 80/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.3927e-04
# Epoch 80: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3925e-04 - val_loss: 2.3938e-04
# Epoch 81/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0890e-04
# Epoch 81: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.0890e-04 - val_loss: 2.2668e-04
# Epoch 82/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3081e-04
# Epoch 82: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.3071e-04 - val_loss: 2.0849e-04
# Epoch 83/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4038e-04
# Epoch 83: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4038e-04 - val_loss: 2.1049e-04
# Epoch 84/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5471e-04
# Epoch 84: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.5544e-04 - val_loss: 2.2292e-04
# Epoch 85/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4379e-04
# Epoch 85: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4379e-04 - val_loss: 2.1699e-04
# Epoch 86/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.3014e-04
# Epoch 86: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3000e-04 - val_loss: 2.1639e-04
# Epoch 87/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3277e-04
# Epoch 87: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3277e-04 - val_loss: 2.1990e-04
# Epoch 88/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4812e-04
# Epoch 88: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4798e-04 - val_loss: 2.2197e-04
# Epoch 89/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5794e-04
# Epoch 89: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5794e-04 - val_loss: 2.4049e-04
# Epoch 90/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3936e-04
# Epoch 90: val_loss did not improve from 0.00019
# 714/714 [==============================] - 17s 24ms/step - loss: 4.3936e-04 - val_loss: 2.2916e-04
# Epoch 91/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0346e-04
# Epoch 91: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.0346e-04 - val_loss: 2.2606e-04
# Epoch 92/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2935e-04
# Epoch 92: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2928e-04 - val_loss: 2.6015e-04
# Epoch 93/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6490e-04
# Epoch 93: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6490e-04 - val_loss: 2.1766e-04
# Epoch 94/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4342e-04
# Epoch 94: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4323e-04 - val_loss: 2.1806e-04
# Epoch 95/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.3755e-04
# Epoch 95: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3739e-04 - val_loss: 2.1751e-04
# Epoch 96/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7769e-04
# Epoch 96: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7752e-04 - val_loss: 2.4099e-04
# Epoch 97/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2856e-04
# Epoch 97: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2842e-04 - val_loss: 2.0609e-04
# Epoch 98/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3188e-04
# Epoch 98: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3188e-04 - val_loss: 2.1549e-04
# Epoch 99/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.3017e-04
# Epoch 99: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3003e-04 - val_loss: 2.1883e-04
# Epoch 100/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1274e-04
# Epoch 100: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.1261e-04 - val_loss: 2.2883e-04
# Epoch 101/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.8048e-04
# Epoch 101: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.8074e-04 - val_loss: 2.2268e-04
# Epoch 102/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3212e-04
# Epoch 102: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3153e-04 - val_loss: 2.1243e-04
# Epoch 103/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.8507e-04
# Epoch 103: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.8439e-04 - val_loss: 2.2671e-04
# Epoch 104/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.3778e-04
# Epoch 104: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3807e-04 - val_loss: 2.1701e-04
# Epoch 105/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5637e-04
# Epoch 105: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.5609e-04 - val_loss: 2.3258e-04
# Epoch 106/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4903e-04
# Epoch 106: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4903e-04 - val_loss: 2.5538e-04
# Epoch 107/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3369e-04
# Epoch 107: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.3312e-04 - val_loss: 2.2097e-04
# Epoch 108/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1702e-04
# Epoch 108: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.1654e-04 - val_loss: 2.1245e-04
# Epoch 109/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5898e-04
# Epoch 109: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5931e-04 - val_loss: 2.7458e-04
# Epoch 110/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5651e-04
# Epoch 110: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.5632e-04 - val_loss: 2.2261e-04
# Epoch 111/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2079e-04
# Epoch 111: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.2079e-04 - val_loss: 2.2083e-04
# Epoch 112/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5280e-04
# Epoch 112: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 23ms/step - loss: 4.5266e-04 - val_loss: 2.4343e-04
# Epoch 113/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5176e-04
# Epoch 113: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5177e-04 - val_loss: 2.2007e-04
# Epoch 114/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4280e-04
# Epoch 114: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.4280e-04 - val_loss: 2.2270e-04
# Epoch 115/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6750e-04
# Epoch 115: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.6750e-04 - val_loss: 2.5016e-04
# Epoch 116/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3082e-04
# Epoch 116: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.3024e-04 - val_loss: 2.0960e-04
# Epoch 117/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3934e-04
# Epoch 117: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.3889e-04 - val_loss: 2.1623e-04
# Epoch 118/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7128e-04
# Epoch 118: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.7110e-04 - val_loss: 2.0905e-04
# Epoch 119/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2763e-04
# Epoch 119: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2731e-04 - val_loss: 2.3696e-04
# Epoch 120/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6897e-04
# Epoch 120: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.6897e-04 - val_loss: 2.4654e-04
# Epoch 121/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1888e-04
# Epoch 121: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.1872e-04 - val_loss: 2.2055e-04
# Epoch 122/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2121e-04
# Epoch 122: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2108e-04 - val_loss: 2.1809e-04
# Epoch 123/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5597e-04
# Epoch 123: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5649e-04 - val_loss: 2.8474e-04
# Epoch 124/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1947e-04
# Epoch 124: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.1947e-04 - val_loss: 2.4314e-04
# Epoch 125/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5388e-04
# Epoch 125: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5354e-04 - val_loss: 2.2303e-04
# Epoch 126/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0082e-04
# Epoch 126: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.0082e-04 - val_loss: 2.0403e-04
# Epoch 127/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1316e-04
# Epoch 127: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1306e-04 - val_loss: 2.4138e-04
# Epoch 128/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3790e-04
# Epoch 128: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.3790e-04 - val_loss: 2.4246e-04
# Epoch 129/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2056e-04
# Epoch 129: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 23ms/step - loss: 4.2056e-04 - val_loss: 2.3214e-04
# Epoch 130/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0719e-04
# Epoch 130: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.0719e-04 - val_loss: 2.2434e-04
# Epoch 131/300
# 714/714 [==============================] - ETA: 0s - loss: 3.9591e-04
# Epoch 131: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9591e-04 - val_loss: 2.2221e-04
# Epoch 132/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.0962e-04
# Epoch 132: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.0955e-04 - val_loss: 2.1444e-04
# Epoch 133/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5893e-04
# Epoch 133: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.5856e-04 - val_loss: 2.5320e-04
# Epoch 134/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2418e-04
# Epoch 134: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.2418e-04 - val_loss: 2.7164e-04
# Epoch 135/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1836e-04
# Epoch 135: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.1891e-04 - val_loss: 2.3090e-04
# Epoch 136/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2394e-04
# Epoch 136: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.2387e-04 - val_loss: 2.6931e-04
# Epoch 137/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4497e-04
# Epoch 137: val_loss did not improve from 0.00019
# 714/714 [==============================] - 16s 22ms/step - loss: 4.4497e-04 - val_loss: 2.2922e-04
# Epoch 138/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2920e-04
# Epoch 138: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.2912e-04 - val_loss: 2.1494e-04
# Epoch 139/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4103e-04
# Epoch 139: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.4084e-04 - val_loss: 2.3386e-04
# Epoch 140/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.0523e-04
# Epoch 140: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0511e-04 - val_loss: 2.1245e-04
# Epoch 141/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6915e-04
# Epoch 141: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.6896e-04 - val_loss: 2.2491e-04
# Epoch 142/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0032e-04
# Epoch 142: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.0032e-04 - val_loss: 2.0685e-04
# Epoch 143/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4165e-04
# Epoch 143: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.4184e-04 - val_loss: 2.1439e-04
# Epoch 144/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7266e-04
# Epoch 144: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.7266e-04 - val_loss: 2.2565e-04
# Epoch 145/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1080e-04
# Epoch 145: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1080e-04 - val_loss: 2.0541e-04
# Epoch 146/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9900e-04
# Epoch 146: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9894e-04 - val_loss: 1.9459e-04
# Epoch 147/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4310e-04
# Epoch 147: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.4294e-04 - val_loss: 2.1048e-04
# Epoch 148/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3768e-04
# Epoch 148: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.3768e-04 - val_loss: 2.2961e-04
# Epoch 149/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4082e-04
# Epoch 149: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.4073e-04 - val_loss: 2.3796e-04
# Epoch 150/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.8172e-04
# Epoch 150: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8168e-04 - val_loss: 2.6170e-04
# Epoch 151/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5086e-04
# Epoch 151: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.5086e-04 - val_loss: 2.1530e-04
# Epoch 152/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4236e-04
# Epoch 152: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4195e-04 - val_loss: 2.2586e-04
# Epoch 153/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5029e-04
# Epoch 153: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.4974e-04 - val_loss: 2.1096e-04
# Epoch 154/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2144e-04
# Epoch 154: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.2144e-04 - val_loss: 2.0924e-04
# Epoch 155/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.0376e-04
# Epoch 155: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0356e-04 - val_loss: 2.0636e-04
# Epoch 156/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1908e-04
# Epoch 156: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1843e-04 - val_loss: 2.0725e-04
# Epoch 157/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.8759e-04
# Epoch 157: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.8741e-04 - val_loss: 2.0919e-04
# Epoch 158/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2992e-04
# Epoch 158: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2975e-04 - val_loss: 2.2304e-04
# Epoch 159/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1719e-04
# Epoch 159: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1732e-04 - val_loss: 2.1882e-04
# Epoch 160/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4905e-04
# Epoch 160: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4905e-04 - val_loss: 2.1574e-04
# Epoch 161/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1884e-04
# Epoch 161: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1866e-04 - val_loss: 2.1657e-04
# Epoch 162/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1567e-04
# Epoch 162: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1550e-04 - val_loss: 2.1445e-04
# Epoch 163/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2674e-04
# Epoch 163: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2674e-04 - val_loss: 2.3577e-04
# Epoch 164/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3474e-04
# Epoch 164: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.3434e-04 - val_loss: 2.1931e-04
# Epoch 165/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1397e-04
# Epoch 165: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1383e-04 - val_loss: 2.1176e-04
# Epoch 166/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1728e-04
# Epoch 166: val_loss did not improve from 0.00019
# 714/714 [==============================] - 17s 24ms/step - loss: 4.1735e-04 - val_loss: 2.0640e-04
# Epoch 167/300
# 714/714 [==============================] - ETA: 0s - loss: 4.2395e-04
# Epoch 167: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 22ms/step - loss: 4.2395e-04 - val_loss: 2.3871e-04
# Epoch 168/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4033e-04
# Epoch 168: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4033e-04 - val_loss: 2.0181e-04
# Epoch 169/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1720e-04
# Epoch 169: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1708e-04 - val_loss: 2.2688e-04
# Epoch 170/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4902e-04
# Epoch 170: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4890e-04 - val_loss: 2.0365e-04
# Epoch 171/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8572e-04
# Epoch 171: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8572e-04 - val_loss: 2.1164e-04
# Epoch 172/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.4062e-04
# Epoch 172: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4029e-04 - val_loss: 2.3196e-04
# Epoch 173/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1154e-04
# Epoch 173: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1154e-04 - val_loss: 2.1900e-04
# Epoch 174/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4440e-04
# Epoch 174: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4438e-04 - val_loss: 2.2009e-04
# Epoch 175/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9653e-04
# Epoch 175: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0486e-04 - val_loss: 2.3496e-04
# Epoch 176/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0931e-04
# Epoch 176: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0931e-04 - val_loss: 2.4781e-04
# Epoch 177/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9472e-04
# Epoch 177: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9542e-04 - val_loss: 2.3330e-04
# Epoch 178/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.8938e-04
# Epoch 178: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8950e-04 - val_loss: 2.8509e-04
# Epoch 179/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9248e-04
# Epoch 179: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9251e-04 - val_loss: 2.1223e-04
# Epoch 180/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2929e-04
# Epoch 180: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2912e-04 - val_loss: 2.1600e-04
# Epoch 181/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4614e-04
# Epoch 181: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4614e-04 - val_loss: 2.1222e-04
# Epoch 182/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.9704e-04
# Epoch 182: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9692e-04 - val_loss: 2.2217e-04
# Epoch 183/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2008e-04
# Epoch 183: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1968e-04 - val_loss: 2.2109e-04
# Epoch 184/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.9747e-04
# Epoch 184: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9749e-04 - val_loss: 2.0930e-04
# Epoch 185/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1096e-04
# Epoch 185: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1045e-04 - val_loss: 2.3363e-04
# Epoch 186/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4189e-04
# Epoch 186: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.4189e-04 - val_loss: 2.2088e-04
# Epoch 187/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.9739e-04
# Epoch 187: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9724e-04 - val_loss: 2.2543e-04
# Epoch 188/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2466e-04
# Epoch 188: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2421e-04 - val_loss: 2.3767e-04
# Epoch 189/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7619e-04
# Epoch 189: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.7592e-04 - val_loss: 2.1474e-04
# Epoch 190/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.0068e-04
# Epoch 190: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0017e-04 - val_loss: 2.6632e-04
# Epoch 191/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1843e-04
# Epoch 191: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1933e-04 - val_loss: 2.4218e-04
# Epoch 192/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2038e-04
# Epoch 192: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1986e-04 - val_loss: 2.3954e-04
# Epoch 193/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0982e-04
# Epoch 193: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0982e-04 - val_loss: 2.2177e-04
# Epoch 194/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2620e-04
# Epoch 194: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2569e-04 - val_loss: 2.2616e-04
# Epoch 195/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.0990e-04
# Epoch 195: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0946e-04 - val_loss: 2.2806e-04
# Epoch 196/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9849e-04
# Epoch 196: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9803e-04 - val_loss: 2.2843e-04
# Epoch 197/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2028e-04
# Epoch 197: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1976e-04 - val_loss: 3.0169e-04
# Epoch 198/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9973e-04
# Epoch 198: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0000e-04 - val_loss: 2.2109e-04
# Epoch 199/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3295e-04
# Epoch 199: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.3249e-04 - val_loss: 2.4458e-04
# Epoch 200/300
# ...
# 713/714 [============================>.] - ETA: 0s - loss: 4.0137e-04
# Epoch 232: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0127e-04 - val_loss: 2.4344e-04
# Epoch 233/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0225e-04
# Epoch 233: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0225e-04 - val_loss: 2.7820e-04
# Epoch 234/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1914e-04
# Epoch 234: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1866e-04 - val_loss: 2.2169e-04
# Epoch 235/300
# 714/714 [==============================] - ETA: 0s - loss: 3.7522e-04
# Epoch 235: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.7522e-04 - val_loss: 2.3776e-04
# Epoch 236/300
# 714/714 [==============================] - ETA: 0s - loss: 3.6353e-04
# Epoch 236: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.6353e-04 - val_loss: 2.3016e-04
# Epoch 237/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2516e-04
# Epoch 237: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2598e-04 - val_loss: 2.4024e-04
# Epoch 238/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1087e-04
# Epoch 238: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1035e-04 - val_loss: 2.1658e-04
# Epoch 239/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9119e-04
# Epoch 239: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9069e-04 - val_loss: 2.0900e-04
# Epoch 240/300
# 714/714 [==============================] - ETA: 0s - loss: 3.6689e-04
# Epoch 240: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.6689e-04 - val_loss: 2.1226e-04
# Epoch 241/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8685e-04
# Epoch 241: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8685e-04 - val_loss: 2.2370e-04
# Epoch 242/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.0246e-04
# Epoch 242: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0199e-04 - val_loss: 2.3194e-04
# Epoch 243/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.5823e-04
# Epoch 243: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.5808e-04 - val_loss: 2.3871e-04
# Epoch 244/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.1999e-04
# Epoch 244: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1952e-04 - val_loss: 2.1832e-04
# Epoch 245/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8496e-04
# Epoch 245: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8496e-04 - val_loss: 2.2437e-04
# Epoch 246/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0353e-04
# Epoch 246: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0353e-04 - val_loss: 2.2210e-04
# Epoch 247/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.9696e-04
# Epoch 247: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9682e-04 - val_loss: 2.1844e-04
# Epoch 248/300
# 714/714 [==============================] - ETA: 0s - loss: 3.6729e-04
# Epoch 248: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.6729e-04 - val_loss: 2.1168e-04
# Epoch 249/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9044e-04
# Epoch 249: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9002e-04 - val_loss: 2.1549e-04
# Epoch 250/300
# 714/714 [==============================] - ETA: 0s - loss: 3.7514e-04
# Epoch 250: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7514e-04 - val_loss: 2.4194e-04
# Epoch 251/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8116e-04
# Epoch 251: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8116e-04 - val_loss: 2.3222e-04
# Epoch 252/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.8848e-04
# Epoch 252: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8807e-04 - val_loss: 2.2222e-04
# Epoch 253/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.9200e-04
# Epoch 253: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9183e-04 - val_loss: 2.2300e-04
# Epoch 254/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8059e-04
# Epoch 254: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8059e-04 - val_loss: 2.1671e-04
# Epoch 255/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.8159e-04
# Epoch 255: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8163e-04 - val_loss: 2.0964e-04
# Epoch 256/300
# 714/714 [==============================] - ETA: 0s - loss: 3.7578e-04
# Epoch 256: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7578e-04 - val_loss: 2.7498e-04
# Epoch 257/300
# 714/714 [==============================] - ETA: 0s - loss: 3.9114e-04
# Epoch 257: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9114e-04 - val_loss: 2.0836e-04
# Epoch 258/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1012e-04
# Epoch 258: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.1012e-04 - val_loss: 2.0925e-04
# Epoch 259/300
# 714/714 [==============================] - ETA: 0s - loss: 3.5385e-04
# Epoch 259: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.5385e-04 - val_loss: 2.3548e-04
# Epoch 260/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2601e-04
# Epoch 260: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.2551e-04 - val_loss: 2.3764e-04
# Epoch 261/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8538e-04
# Epoch 261: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8538e-04 - val_loss: 2.1780e-04
# Epoch 262/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7663e-04
# Epoch 262: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.7634e-04 - val_loss: 2.1755e-04
# Epoch 263/300
# 714/714 [==============================] - ETA: 0s - loss: 3.6824e-04
# Epoch 263: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.6824e-04 - val_loss: 2.6431e-04
# Epoch 264/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.5505e-04
# Epoch 264: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.5491e-04 - val_loss: 2.2204e-04
# Epoch 265/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.7578e-04
# Epoch 265: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.7567e-04 - val_loss: 2.0901e-04
# Epoch 266/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9688e-04
# Epoch 266: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.9648e-04 - val_loss: 2.1469e-04
# Epoch 267/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7221e-04
# Epoch 267: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7205e-04 - val_loss: 2.0759e-04
# Epoch 268/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8890e-04
# Epoch 268: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8890e-04 - val_loss: 2.1326e-04
# Epoch 269/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7553e-04
# Epoch 269: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7562e-04 - val_loss: 2.1404e-04
# Epoch 270/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.6428e-04
# Epoch 270: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.6414e-04 - val_loss: 2.0779e-04
# Epoch 271/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.0108e-04
# Epoch 271: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 4.0095e-04 - val_loss: 2.4209e-04
# Epoch 272/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.6325e-04
# Epoch 272: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.6307e-04 - val_loss: 2.1074e-04
# Epoch 273/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.4768e-04
# Epoch 273: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.4722e-04 - val_loss: 2.2353e-04
# Epoch 274/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8365e-04
# Epoch 274: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.8365e-04 - val_loss: 2.3331e-04
# Epoch 275/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9306e-04
# Epoch 275: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9245e-04 - val_loss: 2.1789e-04
# Epoch 276/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.0673e-04
# Epoch 276: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0673e-04 - val_loss: 2.0933e-04
# Epoch 277/300
# 714/714 [==============================] - ETA: 0s - loss: 3.6434e-04
# Epoch 277: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.6434e-04 - val_loss: 2.0768e-04
# Epoch 278/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7546e-04
# Epoch 278: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.7507e-04 - val_loss: 2.0576e-04
# Epoch 279/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9067e-04
# Epoch 279: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9178e-04 - val_loss: 2.2920e-04
# Epoch 280/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.6226e-04
# Epoch 280: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.6197e-04 - val_loss: 2.1444e-04
# Epoch 281/300
# 714/714 [==============================] - ETA: 0s - loss: 3.4815e-04
# Epoch 281: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.4815e-04 - val_loss: 2.3338e-04
# Epoch 282/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.5281e-04
# Epoch 282: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.5276e-04 - val_loss: 2.0877e-04
# Epoch 283/300
# 714/714 [==============================] - ETA: 0s - loss: 3.7655e-04
# Epoch 283: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7655e-04 - val_loss: 2.2404e-04
# Epoch 284/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7701e-04
# Epoch 284: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7716e-04 - val_loss: 2.2278e-04
# Epoch 285/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.6234e-04
# Epoch 285: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.6226e-04 - val_loss: 2.1585e-04
# Epoch 286/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7246e-04
# Epoch 286: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.7240e-04 - val_loss: 2.1315e-04
# Epoch 287/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.6056e-04
# Epoch 287: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 20ms/step - loss: 3.6043e-04 - val_loss: 2.2232e-04
# Epoch 288/300
# 714/714 [==============================] - ETA: 0s - loss: 3.9948e-04
# Epoch 288: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9948e-04 - val_loss: 2.1618e-04
# Epoch 289/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.7021e-04
# Epoch 289: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7059e-04 - val_loss: 2.2266e-04
# Epoch 290/300
# 714/714 [==============================] - ETA: 0s - loss: 3.5149e-04
# Epoch 290: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.5149e-04 - val_loss: 2.3733e-04
# Epoch 291/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.8663e-04
# Epoch 291: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8830e-04 - val_loss: 2.2134e-04
# Epoch 292/300
# 712/714 [============================>.] - ETA: 0s - loss: 3.9789e-04
# Epoch 292: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.9731e-04 - val_loss: 2.0538e-04
# Epoch 293/300
# 714/714 [==============================] - ETA: 0s - loss: 3.7183e-04
# Epoch 293: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7183e-04 - val_loss: 2.4388e-04
# Epoch 294/300
# 714/714 [==============================] - ETA: 0s - loss: 3.8398e-04
# Epoch 294: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.8398e-04 - val_loss: 2.0477e-04
# Epoch 295/300
# 714/714 [==============================] - ETA: 0s - loss: 4.0469e-04
# Epoch 295: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.0469e-04 - val_loss: 2.1052e-04
# Epoch 296/300
# 714/714 [==============================] - ETA: 0s - loss: 3.4098e-04
# Epoch 296: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.4098e-04 - val_loss: 2.2570e-04
# Epoch 297/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1400e-04
# Epoch 297: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 4.1383e-04 - val_loss: 2.0730e-04
# Epoch 298/300
# 714/714 [==============================] - ETA: 0s - loss: 3.7945e-04
# Epoch 298: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7945e-04 - val_loss: 2.1354e-04
# Epoch 299/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.7105e-04
# Epoch 299: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.7103e-04 - val_loss: 2.0965e-04
# Epoch 300/300
# 713/714 [============================>.] - ETA: 0s - loss: 3.5403e-04
# Epoch 300: val_loss did not improve from 0.00019
# 714/714 [==============================] - 15s 21ms/step - loss: 3.5397e-04 - val_loss: 2.2394e-04

# %%
# Vẽ biểu đồ train_loss và val_loss
print("Train loss và Val loss của data cách 2 giờ")
plot_loss_model(history_t_2)
print()
print("Train loss và Val loss của data cách 4 giờ")
plot_loss_model(history_t_4)
print()
print("Train loss và Val loss của data cách 6 giờ")
plot_loss_model(history_t_6)
print()
print("Train loss và Val loss của data cách 8 giờ")
plot_loss_model(history_t_8)
# Out:
# Train loss và Val loss của data cách 8 giờ

# %%
# Đánh giá mô hình trên tập test
print("Đánh giá mô hình Bi-LSTM với data cách 2 giờ")
y_pred_t_2 = evaluate(model_t_2, X_test_t_2, y_test_t_2)
print()
print("Đánh giá mô hình Bi-LSTM với data cách 4 giờ")
y_pred_t_4 = evaluate(model_t_4, X_test_t_4, y_test_t_4)
print()
print("Đánh giá mô hình Bi-LSTM với data cách 6 giờ")
y_pred_t_6 = evaluate(model_t_6, X_test_t_6, y_test_t_6)
print()
print("Đánh giá mô hình Bi-LSTM với data cách 8 giờ")
y_pred_t_8 = evaluate(model_t_8, X_test_t_8, y_test_t_8)
# Out:
# Đánh giá mô hình Bi-LSTM với data cách 8 giờ
# 115/115 [==============================] - 1s 5ms/step
# Mean Squared Error (MSE) on test set: 0.00013969598766728762
# Mean Absolute Error (MAE) on test set: 0.007344485525404277
# R-squared (R2) on test set: 0.8267574393736898
# Root Mean Squared Error (RMSE) on test set: 0.01181930571849665
# Root Mean Absolute Error (RMAE) on test set: 0.08569997389383661

# %%
# # Chuẩn hóa lại dữ liệu sau để vẽ mô hình
y_pred_predict_t_2, y_test_t_2 = inverse_transform_data(scaler_t_2, y_pred_t_2, y_test_t_2)
y_pred_predict_t_4, y_test_t_4 = inverse_transform_data(scaler_t_4, y_pred_t_4, y_test_t_4)
y_pred_predict_t_6, y_test_t_6 = inverse_transform_data(scaler_t_6, y_pred_t_6, y_test_t_6)
y_pred_predict_t_8, y_test_t_8 = inverse_transform_data(scaler_t_8, y_pred_t_8, y_test_t_8)

# Vẽ các hình data gốc
# print("Dữ liệu gốc cách 2 giờ")
# plot_data_goc(df_t_2)
# print()
# print("Dữ liệu gốc cách 4 giờ")
# plot_data_goc(df_t_4)
# print()
# print("Dữ liệu gốc cách 6 giờ")
# plot_data_goc(df_t_6)
# print()
# print("Dữ liệu gốc cách 8 giờ")
# plot_data_goc(df_t_8)
# print()

# Biểu đồ giá trị dự đoán và thực tế trên tập test
print("Dữ liệu dự đoán với dữ liệu cách 2 giờ")
plot_data_predict(y_test_t_2, y_pred_predict_t_2)
print()
print("Dữ liệu dự đoán với dữ liệu cách 4 giờ")
plot_data_predict(y_test_t_4, y_pred_predict_t_4)
print()
print("Dữ liệu dự đoán với dữ liệu cách 6 giờ")
plot_data_predict(y_test_t_6, y_pred_predict_t_6)
print()
print("Dữ liệu dự đoán với dữ liệu cách 8 giờ")
plot_data_predict(y_test_t_8, y_pred_predict_t_8)
print()

# Biểu đồ giá trị dự đoán và giá trị thực tế ở điểm bất thường trên tập test
print("Dữ liệu dự đoán bất thường với dữ liệu cách 2 giờ")
plot_bat_thuong_test(y_test_t_2, y_pred_predict_t_2)
print()
print("Dữ liệu dự đoán bất thường với dữ liệu cách 4 giờ")
plot_bat_thuong_test(y_test_t_4, y_pred_predict_t_4)
print()
print("Dữ liệu dự đoán bất thường với dữ liệu cách 6 giờ")
plot_bat_thuong_test(y_test_t_6, y_pred_predict_t_6)
print()
print("Dữ liệu dự đoán bất thường với dữ liệu cách 8 giờ")
plot_bat_thuong_test(y_test_t_8, y_pred_predict_t_8)
print()

# Vẽ biểu đồ tại điểm bất thường trên dữ liệu gốc
print("Điểm bất thường trên dữ liệu gốc cách 2 giờ")
plot_data_chi_dinh(scaler_t_2, model_t_2, X_train_t_2, y_train_t_2)
print()
print("Điểm bất thường trên dữ liệu gốc cách 4 giờ")
plot_data_chi_dinh(scaler_t_4, model_t_4, X_train_t_4, y_train_t_4)
print()
print("Điểm bất thường trên dữ liệu gốc cách 6 giờ")
plot_data_chi_dinh(scaler_t_6, model_t_6, X_train_t_6, y_train_t_6)
print()
print("Điểm bất thường trên dữ liệu gốc cách 8 giờ")
plot_data_chi_dinh(scaler_t_8, model_t_8, X_train_t_8, y_train_t_8)
# Out:
# Dữ liệu dự đoán với dữ liệu cách 8 giờ
# Dữ liệu dự đoán bất thường với dữ liệu cách 8 giờ
# Điểm bất thường trên dữ liệu gốc cách 8 giờ
# 58/58 [==============================] - 0s 5ms/step
