# %% [markdown]
# # Import thư viện

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Flatten, GRU
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Đọc dữ liệu

# %%
# Đọc dữ liệu vào DataFrame
df_t_2 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_2\TongMua_KaNak_AnKhe_t-2.csv')
df_t_4 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_4\TongMua_KaNak_AnKhe_t-4.csv')
df_t_6 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_6\TongMua_KaNak_AnKhe_t-6.csv')
df_t_8 = pd.read_csv(r'E:\CoChau\Fair_2024_LSTM_GA-LSTM_BiLSTM_GA-BiLSTM\Code\data\data_t_8\TongMua_KaNak_AnKhe_t-8.csv')

# Xử lý dữ liệu bị thiếu
df_t_2 = df_t_2.dropna()
df_t_4 = df_t_4.dropna()
df_t_6 = df_t_6.dropna()
df_t_8 = df_t_8.dropna()

# %% [markdown]
# # Tạo dữ liệu huấn luyện

# %%
def create_dataset(X, y, n_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:i+n_steps])
        ys.append(y[i+n_steps])
    return np.array(Xs), np.array(ys)

# %% [markdown]
# # Chuẩn hóa và chia bộ dữ liệu cho mô hình LSTM

# %%
# Chuẩn hóa dữ liệu
def scaler(df, time_steps):
    scaler = MinMaxScaler()
    X = df[['Tổng lưu lượng xả (m³/s)[Thực tế]', 'Lưu lượng đến hồ (m³/s)', 'Sum_Mua']]
    y = df[['Lưu lượng đến hồ (m³/s)']]
    X = scaler.fit_transform(X)
    y = scaler.fit_transform(y)

    # Tạo nhãn cho dữ liệu
    X_data, y_data = create_dataset(X, y, time_steps)

    return scaler, X_data, y_data

# %%
# Chuẩn hóa dữ liệu
def split_data(X_data, y_data, time_steps):
    # Chia dữ liệu thành tập huấn luyện, kiểm tra và test
    train_length = int(len(X_data) * 0.7)
    val_length = int((len(X_data) - train_length) / 2)

    X_train, y_train = X_data[:train_length], y_data[:train_length]
    X_val, y_val = X_data[train_length:train_length+val_length], y_data[train_length:train_length+val_length]
    X_test, y_test = X_data[-val_length:], y_data[-val_length:]

    # Reshape dữ liệu đầu vào
    X_train = X_train.reshape(X_train.shape[0], time_steps, X_train.shape[2])
    X_val = X_val.reshape(X_val.shape[0], time_steps, X_val.shape[2])
    X_test = X_test.reshape(X_test.shape[0], time_steps, X_test.shape[2])

    print("Kích thước tập huấn luyện:", len(X_train))
    print("Kích thước tập validation:", len(X_val))
    print("Kích thước tập kiểm tra:", len(X_test))

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# # Xây dựng mô hình GRU

# %%
def train_model(X_train, y_train, X_val, y_val, epochs, batch_size, save_best_model):
    # Xác định kích thước đầu vào và xây dựng mô hình GRU
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = Sequential()
    model.add(GRU(32, input_shape=input_shape, activation='tanh', return_sequences=False))
    model.add(Dropout(0.5))
    model.add(Dense(1))

    model.summary()

    # Compile mô hình
    model.compile(optimizer=Adam(learning_rate=1e-3), loss='mean_squared_error')

    # Lưu lại model tốt nhất
    model_checkpoint = ModelCheckpoint(save_best_model, save_best_only=True, monitor='val_loss', mode='min', verbose=1)

    # Train the model
    history = model.fit(X_train, y_train, 
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=model_checkpoint)
    
    return model, history

# %%
import matplotlib.pyplot as plt

def plot_loss_model(history):
    # Trích xuất giá trị loss trên tập huấn luyện và kiểm tra
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Vẽ biểu đồ
    plt.figure(figsize=(8, 5))
    plt.plot(train_loss, linestyle='-', label='Train loss')
    plt.plot(val_loss, linestyle='-', label='Val loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train loss and Val loss')
    plt.yscale('log')  # Scale y-axis to logarithmic scale
    plt.legend()  # Thêm nhãn chú thích
    plt.show()

# %% [markdown]
# # Dự đoán trên tập kiểm tra và tính toán các chỉ số

# %%
def evaluate(model, X_test, y_test):
    # Dự đoán trên tập validation
    y_pred = model.predict(X_test)

    # Calculate evaluation metrics
    mse_test = mean_squared_error(y_test, y_pred)
    mae_test = mean_absolute_error(y_test, y_pred)
    r2_test = r2_score(y_test, y_pred)
    rmse_test = sqrt(mse_test)
    rmae_test = sqrt(mae_test)

    # Print evaluation results
    print("Mean Squared Error (MSE) on test set:", mse_test)
    print("Mean Absolute Error (MAE) on test set:", mae_test)
    print("R-squared (R2) on test set:", r2_test)
    print("Root Mean Squared Error (RMSE) on test set:", rmse_test)
    print("Root Mean Absolute Error (RMAE) on test set:", rmae_test)

    return y_pred

# %% [markdown]
# # Hiển thị biểu đồ kết quả

# %%
# Khôi phục dữ liệu sau chuẩn hóa
def inverse_transform_data(scaler, y_pred, y_test):
    y_pred_predict = scaler.inverse_transform(y_pred)
    y_pred_predict = pd.DataFrame(y_pred_predict)

    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test)

    return y_pred_predict, y_test

# %%
def plot_data_goc(df):
    # Vẽ biểu đồ dữ liệu gốc
    plt.figure(figsize=(15, 6))
    plt.plot(df['thoi_gian_KaNak'], df['Tổng lưu lượng xả (m³/s)[Thực tế]'], label='Tổng lưu lượng xả')
    plt.plot(df['thoi_gian_KaNak'], df['Lưu lượng đến hồ (m³/s)'], label='Lưu lượng đến hồ')
    plt.plot(df['thoi_gian_KaNak'], df['Sum_Mua'], label='Tổng lượng mưa')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng (m³/s)')
    plt.title('Biểu đồ lưu lượng')
    plt.legend()
    plt.show()

def plot_data_predict(y_test, y_pred_predict):
    # Biểu đồ giá trị dự đoán và thực tế trên tập test
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_pred_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán trên tập kiểm tra')
    plt.legend()
    plt.show()

def plot_bat_thuong_test(y_test, y_pred_predict):
    # Biểu đồ giá trị dự đoán và giá trị thực tế ở điểm bất thường trên tập test
    plt.figure(figsize=(15, 6))
    plt.plot(y_test, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_pred_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán bất thường trên tập kiểm tra')
    plt.legend()

    # Chỉ hiển thị một đoạn nhỏ của biểu đồ
    start_index = 0
    end_index = 1000
    plt.xlim(start_index, end_index)
    plt.show() 

def plot_data_chi_dinh(scaler, model, X_train, y_train):
    X_data_slipt = X_train[15290:17980]
    y_data_slipt = y_train[15290:17980]

    # Dự đoán trên đoạn dữ liệu chỉ định
    y_data_slipt_predict = model.predict(X_data_slipt)

    # Khôi phục dữ liệu sau chuẩn hóa
    y_data_slipt_predict = scaler.inverse_transform(y_data_slipt_predict)
    y_data_slipt_predict = pd.DataFrame(y_data_slipt_predict)
    y_data_slipt = scaler.inverse_transform(y_data_slipt)
    y_data_slipt = pd.DataFrame(y_data_slipt)

    # Biểu đồ giá trị dự đoán và giá trị thực tế trên đoạn dữ liệu gốc bất kỳ
    plt.figure(figsize=(15, 6))
    plt.plot(y_data_slipt, label='Lưu lượng đến hồ thực tế')
    plt.plot(y_data_slipt_predict, label='Lưu lượng đến hồ dự đoán')
    plt.xlabel('Thời gian')
    plt.ylabel('Lưu lượng đến hồ (m³/s)')
    plt.title('Giá trị dự đoán bất thường trên dữ liệu gốc')
    plt.legend()
    plt.show()

# %% [markdown]
# # Chạy mô hình

# %%
# Các tham số cho mô hình
time_steps = 24 * 3
epochs = 300
batch_size = 24
save_best_model_t_2 = './best_model/Model_GRU_t-2.hdf5'
save_best_model_t_4 = './best_model/Model_GRU_t-4.hdf5'
save_best_model_t_6 = './best_model/Model_GRU_t-6.hdf5'
save_best_model_t_8 = './best_model/Model_GRU_t-8.hdf5'

# Chuẩn hóa dữ liệu
scaler_t_2, X_data_t_2, y_data_t_2 = scaler(df_t_2, time_steps)
scaler_t_4, X_data_t_4, y_data_t_4 = scaler(df_t_4, time_steps)
scaler_t_6, X_data_t_6, y_data_t_6 = scaler(df_t_6, time_steps)
scaler_t_8, X_data_t_8, y_data_t_8 = scaler(df_t_8, time_steps)

# Chia dữ liệu
# print("Data cách 2 giờ")
# X_train_t_2, y_train_t_2, X_val_t_2, y_val_t_2, X_test_t_2, y_test_t_2 = split_data(X_data_t_2, y_data_t_2, time_steps)
# print()
# print("Data cách 4 giờ")
# X_train_t_4, y_train_t_4, X_val_t_4, y_val_t_4, X_test_t_4, y_test_t_4 = split_data(X_data_t_4, y_data_t_4, time_steps)
# print()
# print("Data cách 6 giờ")
# X_train_t_6, y_train_t_6, X_val_t_6, y_val_t_6, X_test_t_6, y_test_t_6 = split_data(X_data_t_6, y_data_t_6, time_steps)
print("Data cách 8 giờ")
X_train_t_8, y_train_t_8, X_val_t_8, y_val_t_8, X_test_t_8, y_test_t_8 = split_data(X_data_t_8, y_data_t_8, time_steps)
# Out:
# Data cách 8 giờ
# Kích thước tập huấn luyện: 17120
# Kích thước tập validation: 3669
# Kích thước tập kiểm tra: 3669

# %%
# Training mô hình
# print("Training mô hình GRU với data cách 2 giờ")
# model_t_2, history_t_2 = train_model(X_train_t_2, y_train_t_2, X_val_t_2, y_val_t_2, 
#                                      epochs, batch_size, save_best_model_t_2)
# print()
# print("Training mô hình GRU với data cách 4 giờ")
# model_t_4, history_t_4 = train_model(X_train_t_4, y_train_t_4, X_val_t_4, y_val_t_4, 
#                                      epochs, batch_size, save_best_model_t_4)
# print()
# print("Training mô hình GRU với data cách 6 giờ")
# model_t_6, history_t_6 = train_model(X_train_t_6, y_train_t_6, X_val_t_6, y_val_t_6, 
#                                      epochs, batch_size, save_best_model_t_6)
print("Training mô hình GRU với data cách 8 giờ")
model_t_8, history_t_8 = train_model(X_train_t_8, y_train_t_8, X_val_t_8, y_val_t_8, 
                                     epochs, batch_size, save_best_model_t_8)


# Vẽ biểu đồ train_loss và val_loss
# print("Train loss và Val loss của data cách 2 giờ")
# plot_loss_model(history_t_2)
# print()
# print("Train loss và Val loss của data cách 4 giờ")
# plot_loss_model(history_t_4)
# print()
# print("Train loss và Val loss của data cách 6 giờ")
# plot_loss_model(history_t_6)
# print()
print("Train loss và Val loss của data cách 8 giờ")
plot_loss_model(history_t_8)
# Out:
# Training mô hình GRU với data cách 8 giờ
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32)                3552
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 3585 (14.00 KB)
# Trainable params: 3585 (14.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/300
# WARNING:tensorflow:From c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 712/714 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 1: val_loss improved from inf to 0.00047, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 13s 16ms/step - loss: 0.0016 - val_loss: 4.6975e-04
# Epoch 2/300
#   9/714 [..............................] - ETA: 10s - loss: 9.7255e-04
# c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 714/714 [==============================] - ETA: 0s - loss: 7.5087e-04
# Epoch 2: val_loss improved from 0.00047 to 0.00037, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 11s 16ms/step - loss: 7.5087e-04 - val_loss: 3.7046e-04
# Epoch 3/300
# 711/714 [============================>.] - ETA: 0s - loss: 6.5754e-04
# Epoch 3: val_loss improved from 0.00037 to 0.00031, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 11s 16ms/step - loss: 6.5683e-04 - val_loss: 3.1058e-04
# Epoch 4/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.3335e-04
# Epoch 4: val_loss improved from 0.00031 to 0.00026, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 11s 15ms/step - loss: 5.3291e-04 - val_loss: 2.6234e-04
# Epoch 5/300
# 714/714 [==============================] - ETA: 0s - loss: 6.4278e-04
# Epoch 5: val_loss improved from 0.00026 to 0.00024, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 11s 15ms/step - loss: 6.4278e-04 - val_loss: 2.4046e-04
# Epoch 6/300
# 711/714 [============================>.] - ETA: 0s - loss: 5.4095e-04
# Epoch 6: val_loss improved from 0.00024 to 0.00021, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 11s 15ms/step - loss: 5.3968e-04 - val_loss: 2.1200e-04
# Epoch 7/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.6029e-04
# Epoch 7: val_loss did not improve from 0.00021
# 714/714 [==============================] - 10s 15ms/step - loss: 5.5967e-04 - val_loss: 2.2423e-04
# Epoch 8/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.6848e-04
# Epoch 8: val_loss did not improve from 0.00021
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6905e-04 - val_loss: 2.3417e-04
# Epoch 9/300
# 711/714 [============================>.] - ETA: 0s - loss: 5.6179e-04
# Epoch 9: val_loss did not improve from 0.00021
# 714/714 [==============================] - 10s 15ms/step - loss: 5.6091e-04 - val_loss: 3.0858e-04
# Epoch 10/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.1535e-04
# Epoch 10: val_loss improved from 0.00021 to 0.00021, saving model to ./best_model\Model_GRU_t-8.hdf5
# 714/714 [==============================] - 10s 15ms/step - loss: 5.1513e-04 - val_loss: 2.0663e-04
# Epoch 11/300
# 711/714 [============================>.] - ETA: 0s - loss: 4
val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6248e-04 - val_loss: 2.4454e-04
# Epoch 98/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5968e-04
# Epoch 98: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6452e-04 - val_loss: 2.0907e-04
# Epoch 99/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7317e-04
# Epoch 99: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.7298e-04 - val_loss: 2.1534e-04
# Epoch 100/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.8244e-04
# Epoch 100: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.8212e-04 - val_loss: 1.9040e-04
# Epoch 101/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.3863e-04
# Epoch 101: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.3764e-04 - val_loss: 1.9317e-04
# Epoch 102/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.9011e-04
# Epoch 102: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.9040e-04 - val_loss: 2.0816e-04
# Epoch 103/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.6183e-04
# Epoch 103: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6085e-04 - val_loss: 2.2902e-04
# Epoch 104/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.6063e-04
# Epoch 104: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6021e-04 - val_loss: 1.8829e-04
# Epoch 105/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.7221e-04
# Epoch 105: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.7130e-04 - val_loss: 1.9447e-04
# Epoch 106/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6885e-04
# Epoch 106: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6866e-04 - val_loss: 1.9198e-04
# Epoch 107/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7205e-04
# Epoch 107: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.7203e-04 - val_loss: 1.9771e-04
# Epoch 108/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3923e-04
# Epoch 108: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.3923e-04 - val_loss: 1.9398e-04
# Epoch 109/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.8639e-04
# Epoch 109: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.8554e-04 - val_loss: 1.8822e-04
# Epoch 110/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.7383e-04
# Epoch 110: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.7333e-04 - val_loss: 1.9628e-04
# Epoch 111/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6818e-04
# Epoch 111: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6818e-04 - val_loss: 1.9173e-04
# Epoch 112/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5876e-04
# Epoch 112: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.5876e-04 - val_loss: 2.2264e-04
# Epoch 113/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5224e-04
# Epoch 113: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.5216e-04 - val_loss: 1.8720e-04
# Epoch 114/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5541e-04
# Epoch 114: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.5522e-04 - val_loss: 1.9111e-04
# Epoch 115/300
# 713/714 [============================>.] - ETA: 0s - loss: 5.1080e-04
# Epoch 115: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 5.1064e-04 - val_loss: 2.2514e-04
# Epoch 116/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.4770e-04
# Epoch 116: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.4775e-04 - val_loss: 1.9197e-04
# Epoch 117/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3761e-04
# Epoch 117: val_loss did not improve from 0.00019
# 714/714 [==============================] - 10s 15ms/step - loss: 4.3761e-04 - val_loss: 2.0673e-04
# Epoch 118/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.6194e-04
# Epoch 118: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6133e-04 - val_loss: 2.0016e-04
# Epoch 119/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.1357e-04
# Epoch 119: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.1353e-04 - val_loss: 2.8127e-04
# Epoch 120/300
# 714/714 [==============================] - ETA: 0s - loss: 4.5494e-04
# Epoch 120: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.5494e-04 - val_loss: 2.0611e-04
# Epoch 121/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3686e-04
# Epoch 121: val_loss did not improve from 0.00019
# 714/714 [==============================] - 11s 15ms/step - loss: 4.3686e-04 - val_loss: 2.0721e-04
# Epoch 122/300
# 710/714 [============================>.] - ETA: 0s - loss: 4.2973e-04
# Epoch 122: val_loss did not improve from 0.00019
# 714/714 [==============================] - 9s 13ms/step - loss: 4.3056e-04 - val_loss: 1.8736e-04
# Epoch 123/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.3743e-04
# Epoch 123: val_loss did not improve from 0.00019
# 714/714 [==============================] - 9s 12ms/step - loss: 4.3805e-04 - val_loss: 2.1476e-04
# Epoch 124/300
# 711/714 [============================>.] - ETA: 0s - loss: 5.0915e-04
# Epoch 124: val_loss did not improve from 0.00019
# 714/714 [==============================] - 9s 12ms/step - loss: 5.0986e-04 - val_loss: 1.8699e-04
# Epoch 125/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1529e-04
# Epoch 125: val_loss did not improve from 0.00019
# 714/714 [==============================] - 9s 13ms/step - loss: 4.1529e-04 - val_loss: 2.3150e-04
# Epoch 126/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.
300
# 711/714 [============================>.] - ETA: 0s - loss: 4.6762e-04
# Epoch 197: val_loss did not improve from 0.00018
# ...
# Epoch 232: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6714e-04 - val_loss: 1.8977e-04
# Epoch 233/300
# 714/714 [==============================] - ETA: 0s - loss: 5.0905e-04
# Epoch 233: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 5.0905e-04 - val_loss: 2.7486e-04
# Epoch 234/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5252e-04
# Epoch 234: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.5329e-04 - val_loss: 2.4108e-04
# Epoch 235/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5265e-04
# Epoch 235: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.5200e-04 - val_loss: 2.0545e-04
# Epoch 236/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6500e-04
# Epoch 236: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6542e-04 - val_loss: 1.9100e-04
# Epoch 237/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7904e-04
# Epoch 237: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.7859e-04 - val_loss: 1.9960e-04
# Epoch 238/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.0217e-04
# Epoch 238: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 5.0174e-04 - val_loss: 1.9713e-04
# Epoch 239/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.2811e-04
# Epoch 239: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.2761e-04 - val_loss: 2.4875e-04
# Epoch 240/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7392e-04
# Epoch 240: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.7392e-04 - val_loss: 2.1149e-04
# Epoch 241/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.8155e-04
# Epoch 241: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.9535e-04 - val_loss: 2.4095e-04
# Epoch 242/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.8749e-04
# Epoch 242: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.8692e-04 - val_loss: 1.8971e-04
# Epoch 243/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3896e-04
# Epoch 243: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.3896e-04 - val_loss: 2.4222e-04
# Epoch 244/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6850e-04
# Epoch 244: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6850e-04 - val_loss: 1.8920e-04
# Epoch 245/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6900e-04
# Epoch 245: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6900e-04 - val_loss: 1.9615e-04
# Epoch 246/300
# 714/714 [==============================] - ETA: 0s - loss: 4.3865e-04
# Epoch 246: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.3865e-04 - val_loss: 1.8644e-04
# Epoch 247/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.8436e-04
# Epoch 247: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.8385e-04 - val_loss: 2.0335e-04
# Epoch 248/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.5060e-04
# Epoch 248: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.5218e-04 - val_loss: 1.9354e-04
# Epoch 249/300
# 714/714 [==============================] - ETA: 0s - loss: 4.9871e-04
# Epoch 249: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.9871e-04 - val_loss: 1.9512e-04
# Epoch 250/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.4566e-04
# Epoch 250: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.4527e-04 - val_loss: 2.0480e-04
# Epoch 251/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6524e-04
# Epoch 251: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6524e-04 - val_loss: 2.0567e-04
# Epoch 252/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.5315e-04
# Epoch 252: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.5345e-04 - val_loss: 1.9770e-04
# Epoch 253/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5510e-04
# Epoch 253: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.5458e-04 - val_loss: 1.8928e-04
# Epoch 254/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7095e-04
# Epoch 254: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.7095e-04 - val_loss: 1.9387e-04
# Epoch 255/300
# 711/714 [============================>.] - ETA: 0s - loss: 5.0274e-04
# Epoch 255: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 5.0213e-04 - val_loss: 2.1093e-04
# Epoch 256/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.4105e-04
# Epoch 256: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.4165e-04 - val_loss: 1.9575e-04
# Epoch 257/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.6740e-04
# Epoch 257: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6716e-04 - val_loss: 2.3504e-04
# Epoch 258/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7018e-04
# Epoch 258: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6955e-04 - val_loss: 1.9105e-04
# Epoch 259/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.7921e-04
# Epoch 259: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.7843e-04 - val_loss: 1.8559e-04
# Epoch 260/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.1584e-04
# Epoch 260: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.1668e-04 - val_loss: 1.9329e-04
# Epoch 261/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.5182e-04
# Epoch 261: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.5210e-04 - val_loss: 2.6176e-04
# Epoch 262/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.6776e-04
# Epoch 262: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.6758e-04 - val_loss: 2.1197e-04
# Epoch 263/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.6984e-04
# Epoch 263: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.7150e-04 - val_loss: 1.9330e-04
# Epoch 264/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.6985e-04
# Epoch 264: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6893e-04 - val_loss: 1.9496e-04
# Epoch 265/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7806e-04
# Epoch 265: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.8005e-04 - val_loss: 2.2826e-04
# Epoch 266/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.8112e-04
# Epoch 266: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 16ms/step - loss: 4.8098e-04 - val_loss: 2.1572e-04
# Epoch 267/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4780e-04
# Epoch 267: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.4780e-04 - val_loss: 1.9256e-04
# Epoch 268/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2455e-04
# Epoch 268: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.2439e-04 - val_loss: 2.6902e-04
# Epoch 269/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7004e-04
# Epoch 269: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.6987e-04 - val_loss: 1.8530e-04
# Epoch 270/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7806e-04
# Epoch 270: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 14ms/step - loss: 4.7788e-04 - val_loss: 2.0238e-04
# Epoch 271/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4561e-04
# Epoch 271: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.4561e-04 - val_loss: 1.9909e-04
# Epoch 272/300
# 714/714 [==============================] - ETA: 0s - loss: 4.1852e-04
# Epoch 272: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.1852e-04 - val_loss: 2.1419e-04
# Epoch 273/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.4625e-04
# Epoch 273: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.4629e-04 - val_loss: 1.9077e-04
# Epoch 274/300
# 712/714 [============================>.] - ETA: 0s - loss: 5.1696e-04
# Epoch 274: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 5.1746e-04 - val_loss: 1.8453e-04
# Epoch 275/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.3858e-04
# Epoch 275: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.4123e-04 - val_loss: 2.0519e-04
# Epoch 276/300
# 710/714 [============================>.] - ETA: 0s - loss: 4.8471e-04
# Epoch 276: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 14ms/step - loss: 4.8336e-04 - val_loss: 2.5849e-04
# Epoch 277/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.7375e-04
# Epoch 277: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 14ms/step - loss: 4.7264e-04 - val_loss: 2.1271e-04
# Epoch 278/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4517e-04
# Epoch 278: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.4517e-04 - val_loss: 2.0299e-04
# Epoch 279/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.2138e-04
# Epoch 279: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.2132e-04 - val_loss: 1.9581e-04
# Epoch 280/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7286e-04
# Epoch 280: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.7294e-04 - val_loss: 1.9697e-04
# Epoch 281/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.6160e-04
# Epoch 281: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6110e-04 - val_loss: 1.8750e-04
# Epoch 282/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5351e-04
# Epoch 282: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 16ms/step - loss: 4.5331e-04 - val_loss: 1.8796e-04
# Epoch 283/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6771e-04
# Epoch 283: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 16ms/step - loss: 4.6756e-04 - val_loss: 2.0151e-04
# Epoch 284/300
# 714/714 [==============================] - ETA: 0s - loss: 4.4687e-04
# Epoch 284: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.4687e-04 - val_loss: 1.9250e-04
# Epoch 285/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.5337e-04
# Epoch 285: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.5321e-04 - val_loss: 2.6613e-04
# Epoch 286/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.5202e-04
# Epoch 286: val_loss did not improve from 0.00018
# 714/714 [==============================] - 10s 15ms/step - loss: 4.5133e-04 - val_loss: 1.9169e-04
# Epoch 287/300
# 714/714 [==============================] - ETA: 0s - loss: 4.6294e-04
# Epoch 287: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 12ms/step - loss: 4.6294e-04 - val_loss: 2.2822e-04
# Epoch 288/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.4707e-04
# Epoch 288: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.4618e-04 - val_loss: 1.9691e-04
# Epoch 289/300
# 710/714 [============================>.] - ETA: 0s - loss: 4.4714e-04
# Epoch 289: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 12ms/step - loss: 4.4732e-04 - val_loss: 1.8898e-04
# Epoch 290/300
# 710/714 [============================>.] - ETA: 0s - loss: 4.5130e-04
# Epoch 290: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.5102e-04 - val_loss: 2.0726e-04
# Epoch 291/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.7705e-04
# Epoch 291: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.7686e-04 - val_loss: 1.9631e-04
# Epoch 292/300
# 710/714 [============================>.] - ETA: 0s - loss: 4.6955e-04
# Epoch 292: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 12ms/step - loss: 4.6852e-04 - val_loss: 2.0232e-04
# Epoch 293/300
# 711/714 [============================>.] - ETA: 0s - loss: 4.5583e-04
# Epoch 293: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 12ms/step - loss: 4.5506e-04 - val_loss: 1.9570e-04
# Epoch 294/300
# 710/714 [============================>.] - ETA: 0s - loss: 4.4474e-04
# Epoch 294: val_loss did not improve from 0.00018
# 714/714 [==============================] - 9s 13ms/step - loss: 4.4608e-04 - val_loss: 1.8644e-04
# Epoch 295/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6733e-04
# Epoch 295: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.6713e-04 - val_loss: 2.0632e-04
# Epoch 296/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.9458e-04
# Epoch 296: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 16ms/step - loss: 4.9448e-04 - val_loss: 2.2092e-04
# Epoch 297/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7774e-04
# Epoch 297: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 15ms/step - loss: 4.7702e-04 - val_loss: 2.2369e-04
# Epoch 298/300
# 712/714 [============================>.] - ETA: 0s - loss: 4.7371e-04
# Epoch 298: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 16ms/step - loss: 4.7318e-04 - val_loss: 1.8613e-04
# Epoch 299/300
# 714/714 [==============================] - ETA: 0s - loss: 4.7598e-04
# Epoch 299: val_loss did not improve from 0.00018
# 714/714 [==============================] - 11s 16ms/step - loss: 4.7598e-04 - val_loss: 2.0315e-04
# Epoch 300/300
# 713/714 [============================>.] - ETA: 0s - loss: 4.6214e-04
# Epoch 300: val_loss did not improve from 0.00018
# 714/714 [==============================] - 12s 16ms/step - loss: 4.6197e-04 - val_loss: 2.2539e-04
# Train loss và Val loss của data cách 8 giờ

# %%
# Đánh giá mô hình trên tập test
# print("Đánh giá mô hình GRU với data cách 2 giờ")
# y_pred_t_2 = evaluate(model_t_2, X_test_t_2, y_test_t_2)
# print()
# print("Đánh giá mô hình GRU với data cách 4 giờ")
# y_pred_t_4 = evaluate(model_t_4, X_test_t_4, y_test_t_4)
# print()
# print("Đánh giá mô hình GRU với data cách 6 giờ")
# y_pred_t_6 = evaluate(model_t_6, X_test_t_6, y_test_t_6)
# print()
print("Đánh giá mô hình GRU với data cách 8 giờ")
y_pred_t_8 = evaluate(model_t_8, X_test_t_8, y_test_t_8)
# Out:
# Đánh giá mô hình GRU với data cách 8 giờ
# 115/115 [==============================] - 1s 5ms/step
# Mean Squared Error (MSE) on test set: 0.00014348189491497477
# Mean Absolute Error (MAE) on test set: 0.007578659289722273
# R-squared (R2) on test set: 0.8220623849427413
# Root Mean Squared Error (RMSE) on test set: 0.011978392835225215
# Root Mean Absolute Error (RMAE) on test set: 0.08705549545963352

# %%
# Chuẩn hóa lại dữ liệu sau để vẽ mô hình
# y_pred_predict_t_2, y_test_t_2 = inverse_transform_data(scaler_t_2, y_pred_t_2, y_test_t_2)
# y_pred_predict_t_4, y_test_t_4 = inverse_transform_data(scaler_t_4, y_pred_t_4, y_test_t_4)
# y_pred_predict_t_6, y_test_t_6 = inverse_transform_data(scaler_t_6, y_pred_t_6, y_test_t_6)
y_pred_predict_t_8, y_test_t_8 = inverse_transform_data(scaler_t_8, y_pred_t_8, y_test_t_8)

# Vẽ các hình data gốc
# print("Dữ liệu gốc cách 2 giờ")
# plot_data_goc(df_t_2)
# print()
# print("Dữ liệu gốc cách 4 giờ")
# plot_data_goc(df_t_4)
# print()
# print("Dữ liệu gốc cách 6 giờ")
# plot_data_goc(df_t_6)
# print()
# print("Dữ liệu gốc cách 8 giờ")
# plot_data_goc(df_t_8)
# print()

# Biểu đồ giá trị dự đoán và thực tế trên tập test
# print("Dữ liệu dự đoán với dữ liệu cách 2 giờ")
# plot_data_predict(y_test_t_2, y_pred_predict_t_2)
# print()
# print("Dữ liệu dự đoán với dữ liệu cách 4 giờ")
# plot_data_predict(y_test_t_4, y_pred_predict_t_4)
# print()
# print("Dữ liệu dự đoán với dữ liệu cách 6 giờ")
# plot_data_predict(y_test_t_6, y_pred_predict_t_6)
# print()
print("Dữ liệu dự đoán với dữ liệu cách 8 giờ")
plot_data_predict(y_test_t_8, y_pred_predict_t_8)
print()

# Biểu đồ giá trị dự đoán và giá trị thực tế ở điểm bất thường trên tập test
# print("Dữ liệu dự đoán bất thường với dữ liệu cách 2 giờ")
# plot_bat_thuong_test(y_test_t_2, y_pred_predict_t_2)
# print()
# print("Dữ liệu dự đoán bất thường với dữ liệu cách 4 giờ")
# plot_bat_thuong_test(y_test_t_4, y_pred_predict_t_4)
# print()
# print("Dữ liệu dự đoán bất thường với dữ liệu cách 6 giờ")
# plot_bat_thuong_test(y_test_t_6, y_pred_predict_t_6)
# print()
print("Dữ liệu dự đoán bất thường với dữ liệu cách 8 giờ")
plot_bat_thuong_test(y_test_t_8, y_pred_predict_t_8)
print()

# Vẽ biểu đồ tại điểm bất thường trên dữ liệu gốc
# print("Điểm bất thường trên dữ liệu gốc cách 2 giờ")
# plot_data_chi_dinh(scaler_t_2, model_t_2, X_train_t_2, y_train_t_2)
# print()
# print("Điểm bất thường trên dữ liệu gốc cách 4 giờ")
# plot_data_chi_dinh(scaler_t_4, model_t_4, X_train_t_4, y_train_t_4)
# print()
# print("Điểm bất thường trên dữ liệu gốc cách 6 giờ")
# plot_data_chi_dinh(scaler_t_6, model_t_6, X_train_t_6, y_train_t_6)
# print()
print("Điểm bất thường trên dữ liệu gốc cách 8 giờ")
plot_data_chi_dinh(scaler_t_8, model_t_8, X_train_t_8, y_train_t_8)
# Out:
# Dữ liệu dự đoán với dữ liệu cách 8 giờ
# Dữ liệu dự đoán bất thường với dữ liệu cách 8 giờ
# Điểm bất thường trên dữ liệu gốc cách 8 giờ
# 58/58 [==============================] - 0s 4ms/step
